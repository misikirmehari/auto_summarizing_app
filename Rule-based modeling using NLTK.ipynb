# %% [markdown]
# # Rule based Modeling using NLTK

# %% [markdown]
# ### Download and Retrieve text and Image from Article

# %% [markdown]
# #### Retrieve text from web page

# %%
# urllib2 used to download a webpage
import urllib.request

# library to parse html page 
from bs4 import BeautifulSoup
articleURL = "https://www.washingtonpost.com/powerpost/female-senators-are-increasingly-on-receiving-end-of-insults-from-male-officials/2017/07/27/6b0b6078-72d7-11e7-9eac-d56bd5568db8_story.html?hpid=hp_hp-top-table-main_gopmen-817pm%3Ahomepage%2Fstory&utm_term=.3ccd7d73c12d"

# downloads the webpage
page = urllib.request.urlopen(articleURL).read().decode('utf8','ignore')

# instantiate a beautifulsoup object 
soup = BeautifulSoup(page,"lxml")

# %% [markdown]
# #### Check if we have downloaded our page correctly

# %%
soup
# Out:
# <!DOCTYPE html>
# <html class="article layout_article rendering-context-www" itemscope="" itemtype="http://schema.org/NewsArticle" lang="en"> <head> <script id="_$cookiemonster">(function(b,m){function d(b,d){this.wl={map:f.map.concat(b||[]),reg:f.reg.concat(d||[])}}var f={reg:[],map:[]};d.prototype.ommNom=function(){return this.nom(!0,void 0)};d.prototype.allows=function(b){return!(-1<this.nom(!1,[b]).indexOf(b))};d.prototype.nom=function(d,f){for(var c=[],l=b.location.hostname.split("").reverse().join("").slice(0,18),g=f||b.cookie.split(";"),a,h,e=0;e<g.length,a=g[e];e++)a=a.trim().split("\x3d")[0].toLowerCase(),-1<this.wl.map.indexOf(a)||c.push(a);for(var k=0;k<this.wl.reg.length,
# h=this.wl.reg[k];k++)for(e=h.lastIndex=0;e<g.length,a=g[e];e++)a=a.trim().split("\x3d")[0].toLowerCase(),h.test(a)?-1<c.indexOf(a)&&c.splice(c.indexOf(a),1):0>c.indexOf(a)&&0>this.wl.map.indexOf(a)&&c.push(a);d&&("moc.tsopnotgnihsaw"==l&&(this.wl.reg.length||this.wl.map.length)?setTimeout(function(a){return function(){for(var a=0;a<c.length;a++)b.cookie=c[a]+"\x3d; expires\x3dThu, 01 Jan 1970 00:00:01 GMT; path\x3d/; domain\x3dwww.washingtonpost.com",b.cookie=c[a]+"\x3d; expires\x3dThu, 01 Jan 1970 00:00:01 GMT; path\x3d/; domain\x3d.washingtonpost.com",
# b.cookie=c[a]+"\x3d; expires\x3dThu, 01 Jan 1970 00:00:01 GMT; path\x3d/; domain\x3d"}}(this),0):console.error("[cookie-monster] Cowardly refusing to delete cookies on "+b.location.hostname,c));return c};return b.__CookieMonster__=d})(document);</script> <script>console.time("header-start");</script> <script>var TWP_Debug=window.TWP_Debug||{};TWP_Debug.initialTime=new Date;window.pageBuilder=window.pageBuilder||{};window.pageBuilder.loadAsyncFeatures=function(){__e=window.__e||[];__e.push(["lazy-scroll",function(){var b=window.document.getElementsByClassName("pb-async");[].slice.call(b).map(function(a){return a.id}).forEach(function(a){window.pageBuilder.loadAsyncFeature(a)})}])};window.pageBuilder.featureLoaded=function(){$(window.document).trigger("dom-manipulation-complete")};</script> <meta content="6b0b6078-72d7-11e7-9eac-d56bd5568db8" name="eomportal-uuid"/> <meta content="1501201870" name="object-hash"/> <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/> <meta charset="utf-8"/> <meta content="width=device-width, initial-scale=1.0, user-scalable=yes, minimum-scale=0.5, maximum-scale=2.0" id="viewport" name="viewport"/> <meta content="unsafe-url" name="referrer"/> <meta content="lisa murkowski, susan collins, murkowski zinke alaska, collins duel blake fahrenthold, collins fahrenthold, buddy carter snatch a knot in their ass, snatch a knot in their ass" name="keywords"/> <meta content="lisa murkowski, susan collins, murkowski zinke alaska, collins duel blake fahrenthold, collins fahrenthold, buddy carter snatch a knot in their ass, snatch a knot in their ass" name="news_keywords"/> <meta name="twitter:site" value="@WashingtonPost"/> <meta content="summary_large_image" name="twitter:card"/> <meta content="article" property="og:type"/> <meta content="Washington Post" property="og:site_name"/> <meta content="True" itemprop="mainEntityOfPage"/> <meta content="https://www.facebook.com/washingtonpost" property="article:publisher"/> <meta content="1513210492" property="fb:admins"/> <meta content="41245586762" property="fb:app_id"/> <meta content="1244584375" property="fb:admins"/> <meta content="4403963" property="fb:admins"/> <meta content="2724956" property="fb:admins"/> <meta content="500835072" property="fb:admins"/> <link href="/pb/resources/json/desktop-notifications-manifest.json" rel="manifest"/> <title>Female senators are increasingly on receiving end of insults from male officials - The Washington Post</title> <link href="https://www.washingtonpost.com/powerpost/female-senators-are-increasingly-on-receiving-end-of-insults-from-male-officials/2017/07/27/6b0b6078-72d7-11e7-9eac-d56bd5568db8_story.html" itemprop="url" rel="canonical"/> <meta content="https://www.washingtonpost.com/powerpost/female-senators-are-increasingly-on-receiving-end-of-insults-from-male-officials/2017/07/27/6b0b6078-72d7-11e7-9eac-d56bd5568db8_story.html" property="og:url"/> <meta content="https://img.washingtonpost.com/rf/image_1484w/2010-2019/WashingtonPost/2017/07/27/National-Politics/Images/Trump_25988-43906.jpg?t=20170517" itemprop="image" property="og:image"/> <meta content="Female senators are increasingly on receiving end of insults from male officials" property="og:title"/> <meta content="Sens. Susan Collins and Lisa Murkowski have been singled out for their skepticism of the GOP’s health-care proposals" itemprop="description" name="description"/> <meta content="Sens. Susan Collins and Lisa Murkowski have been singled out for their skepticism of the GOP’s health-care proposals" property="og:description"/> <meta content="index,follow" name="robots"/> <meta content="normal" name="theme"/> <meta content="" name="audio_url"/> <link href="https://www.washingtonpost.com/amphtml/powerpost/female-senators-are-increasingly-on-receiving-end-of-insults-from-male-officials/2017/07/27/6b0b6078-72d7-11e7-9eac-d56bd5568db8_story.html" rel="amphtml"/> <link href="android-app://com.washingtonpost.rainbow/wp-android-rainbow/www.washingtonpost.co ...
# (function(){try{wp_meta_data=window.wp_meta_data||{},wp_meta_data.platform="pagebuilder","isPageInitiallyHydrated"in wp_meta_data||(wp_meta_data.isPageInitiallyHydrated=!0),wp_meta_data.showAds=!0,wp_meta_data.isPWA=!1,wp_meta_data.showPreRollAds=!1,wp_meta_data.isHomepage=!1,wp_meta_data.isErrorPage=!1,wp_meta_data.isMultimedia=!1,wp_meta_data.wt="article_story",delete wp_meta_data.facet,delete wp_meta_data.contentName,delete wp_meta_data.contentLength,wp_meta_data.page_id=["6b0b6078-72d7-11e7-9eac-d56bd5568db8"],
# wp_meta_data.author=["Elise Viebeck"],wp_meta_data.keywords="lisa murkowski;susan collins;murkowski zinke alaska;collins duel blake fahrenthold;collins fahrenthold;buddy carter snatch a knot in their ass;snatch a knot in their ass".split(";"),wp_meta_data.clavis=wp_meta_data.clavis||{},wp_meta_data.clavis.keywords=[],wp_meta_data.clavis.topics=[],wp_meta_data.clavis.ct=[],delete wp_meta_data.destinations,wp_meta_data.hot_topic=[!1],delete wp_meta_data.subjects,delete wp_meta_data.category,delete wp_meta_data.people_names,
# delete wp_meta_data.people_positions,delete wp_meta_data.organization_names,delete wp_meta_data.coverage_industrys,delete wp_meta_data.ideology,delete wp_meta_data.addresses,delete wp_meta_data.neighborhoods,delete wp_meta_data.zip_codes,delete wp_meta_data.counties,delete wp_meta_data.venues,delete wp_meta_data.cities,delete wp_meta_data.states,delete wp_meta_data.countries,delete wp_meta_data.breaking_news,wp_meta_data.contentType=["article"]}catch(a){}})();</script> <script>window.wpAd={inventory:{interstitial:{size:[],keyvalues:{ad:"interstitial"}},leaderboard:{size:[[728,90],[970,66],[970,250]],keyvalues:{pos:"leaderboard"}},inline_bb:{size:[[300,250],"fluid"],sizeOnCondition:{windowWidth:1250,size:[620,250]}},"inline_bb_*":{size:[[300,250],"fluid"],sizeOnCondition:{windowWidth:1250,size:[620,250]}},flex_ss_bb_hp:{size:[[336,850],[336,280],[160,600],[300,250],[300,600],[300,1050]]},"flex_ss_bb_hp_*":{size:[[336,850],[336,280],[160,600],[300,250],[300,600],[300,1050]]},
# flex_bb_hp:{size:[[336,850],[336,280],[300,600],[300,1050],[300,250]]},tiffany_tile:{size:[[200,60],[184,90]],keyvalues:{ad:["tiffany_tile"]}},"tiffany_tile_*":{size:[[200,60],[184,90]]},brandconnect_front:{size:[[1,8],"fluid"]},bc_pb_homepage:{size:[[1,8],"fluid"]},"336x60":{size:[[336,60]],keyvalues:{ad:["336x60"]}},"336x35_top":{size:[[336,35]],keyvalues:{ad:["336x35"]}},marketing_2:{size:[[1,1]]},marketwatch:{size:[[1,1]]},"88x31":{size:[[88,31]]},bigbox_gallery:{size:[[300,250]]},mob_bigbox:{size:[[300,
# 250],[300,600],"fluid"]},"mob_bigbox_*":{size:[[300,250],"fluid"]},fixedBottom:{size:[[320,50],[300,50]]},pushdown:{size:[[1,1],[970,66],[970,90],[728,90],[970,250]]},bc_bigbox:{size:[[300,250]]},polly_article:{size:[[1,1]]}},exclusionsKeyWords:{natural_disaster:"deepwater;oil spill;shell;exxon;citgo;bp;chevron;hess;sunoco;disaster;fire;explosion;oil;coal;death;dead;quake;earthquake;tsunami;tornado;hurricane;flood;bed bug;infestation;gas".split(";"),human_disaster:"oreilly;Ailes;o'reilly;fox news;abuse;death;trafficking;dead;gunshot;murderer;porn;sex tape;sexting;sexual abuse;molestation;assault;child abuse;sex abuse;ISIS;ISIL;Islamic State;Al Qaeda;Syria;Syrian;Assad;shooter;shooting;migrants;aylan kurdi;refugee crisis;drown;shoot;vatican;spanair;aground;rescue;attack;disaster;explosion;war;hostage;terror;terrorist;bomb;blast;mining;miner;violence;riot;crash;9/11;sept. 11;september 11;behead;United 93;pistorius;ebola;rape;rapist;amtrak;derailment;benghazi;misconduct".split(";"),
# financial_crisis:"corrupt;lawsuit;goldman;aig;foreclosure;enron;sec;mortgage;Insurance;health;bank;wall street;protest;labor strike;union strike;labor issue;union issue;teacher strike;teachers strike;election".split(";"),inappropriate:"porn deepwater gambling sex alcohol pornography".split(" ")},posOnCommericalNode:{"washingtonpost.com":{pos:{leaderboard:{start:"07/12/2017 00:00 EDT",end:"07/12/2017 23:59 EDT"},flex_bb_hp:{start:"06/14/2017 00:00 EDT",end:"12/31/2017 23:59 EDT"},tiffany_tile:{start:"05/24/2017 00:00 EDT",
# end:"12/31/2017 23:59 EDT"},tiffany_tile_2:{start:"05/24/2017 00:00 EDT",end:"12/31/2017 23:59 EDT"},marketwatch:!1,pushdown:{start:"06/21/2017 00:00 EDT",end:"06/22/2017 23:59 EDT"}}},powerpost:{pos:{tiffany_tile:{start:"01/01/2017 00:00 EDT",end:"07/09/2017 00:00 EDT"}}},"powerpost/article":{pos:{tiffany_tile:{start:"01/01/2017 00:00 EDT",end:"07/09/2017 00:00 EDT"}}}}};</script> <script async="" src="https://www.washingtonpost.com/wp-stat/ad/zeus/wp-ad.min.js"></script> <script>window.console&&console.log&&console.log("["+(new Date-TWP_Debug.initialTime)/1E3+"] STARTING load_immediately");</script> <script>console.time("load_immediately");</script> <script src="/pb/gr/c/default/r0z7VYYLti3loq/load_immediately/4697e08d36.js?_=e6d26"></script> <script>console.timeEnd("load_immediately");</script> <script>wp_import.valor(!0);</script> <script>window.wp_pb=window.wp_pb||{};wp_pb.banditoEnv={TIMEOUT:2500,PERF_API:"https://loxodo-ct.ext.nile.works/api/save-perf",TESTS_API:"https://www.washingtonpost.com/bandito/tests-pb/",EVENTS_API:"https://loxodo-ct.ext.nile.works/api/save-event"};</script> <script>window.head_conf={head:"TWPHead"};</script> <script>console.time("head.min.js");</script> <script src="/pb/resources/js/head.min.js"></script> <script>console.timeEnd("head.min.js");</script> <script>console.time("global");</script> <script src="/pb/gr/c/default/r0z7VYYLti3loq/global/ecae3e7968.js?_=b9e93"></script> <script>console.timeEnd("global");</script> <script>console.time("headjs");</script> <script src="/pb/gr/c/default/r0z7VYYLti3loq/headjs/8bb9d8351d.js?_=69d73"></script> <script>console.timeEnd("headjs");</script> <script>console.time("head.js");</script> <script src="/pb/gr/p/default/r0z7VYYLti3loq/head.js?_=c93f7"></script> <script>console.timeEnd("head.js");</script> <script>console.time("exec-header-tracking");</script> <script>(function(){TWP="undefined"==typeof TWP?{}:TWP;TWP.Data="undefined"==typeof TWP.Data?{}:TWP.Data;TWP.Data.Tracking={init:function(){this.props={};this.props.platform="pagebuilder";this.props.site="www.washingtonpost.com";this.props.page_type="";this.props.page_name="powerpost:article - d56bd5568db8 - 20170727 - female-senators-are-increasingly-on-receiving-end-of-insults-from-male-officials";this.props.section="powerpost";this.props.channel="wp - powerpost";this.props.subsection="powerpost";this.props.hierarchy=
# "powerpost|article";this.props.content_type="article";this.props.story_type="";this.props.headline="Female senators are increasingly on receiving end of insults from male officials";this.props.author="Elise Viebeck";this.props.source="The Washington Post";this.props.content_id="6b0b6078-72d7-11e7-9eac-d56bd5568db8";this.props.page_num="";this.props.columnname="";this.props.blogname="";this.props.published="";this.props.news_or_commercial="News";this.props.commercial_node="/powerpost";this.props.content_category=
# "National-Politics";this.props.sectionfront="";this.props.track_scrolling=!0}};TWP.Data.Tracking.init()})();</script> <script>console.timeEnd("exec-header-tracking");</script> <script>console.time("exec-header-review");</script> <script>console.timeEnd("exec-header-review");</script> <script>console.time("exec-header-abtest");</script> <script>console.timeEnd("exec-header-abtest");</script> <script>window.console&&console.log&&console.log("["+(new Date-TWP_Debug.initialTime)/1E3+"] STARTING exec-twp-global");</script> <script>console.time("exec-twp-global");</script> <script>(function(b){var a=[];a.push("//www.washingtonpost.com/pb/gr/c/default/r0z7VYYLti3loq/conf-production/b5411285f6.js?_\x3d81d55");a.push("//www.washingtonpost.com/pb/gr/c/default/r0z7VYYLti3loq/modal-css/938c258067.css?_\x3d874d9");a.push("//www.washingtonpost.com/pb/gr/c/default/r0z7VYYLti3loq/identity-management/da39a3ee5e.js?_\x3db7dfb");a.push("https://www.washingtonpost.com/wp-stat/pwapi/prod/wpPwapi1-min.js?token\x3d201706011309EST");a.push("//www.washingtonpost.com/pb/gr/c/default/r0z7VYYLti3loq/identity-management/c4d7fa1f35.js?_\x3db7dfb");
# a.push("//www.washingtonpost.com/wp-stat/analytics/latest/main.js?token\x3d20170722236PST");a.push("//www.washingtonpost.com/wp-stat/advertising/pseudo-static/identity-retargeting.js");"undefined"===typeof b.jqm&&a.unshift("//www.washingtonpost.com/pb/gr/c/default/r0z7VYYLti3loq/jqmodal/7a5b554023.js?_\x3da9337");"undefined"===typeof b.cookie&&a.unshift("//www.washingtonpost.com/pb/gr/c/default/r0z7VYYLti3loq/jquery-cookie/4cc3c1bef0.js?_\x3db8874");"undefined"===typeof jQuery&&a.unshift("//www.washingtonpost.com/pb/gr/c/default/r0z7VYYLti3loq/jquery/c85562b39d.js?_\x3db45ba");
# window.head_conf={head:"TWPHead"};console.time("ResourceBundle pb-r-identity");if("undefined"==typeof window.TWPHead){b=document.createElement("script");b.onload=b.onreadystatechange=function(){this.readyState&&"complete"!=this.readyState&&"loaded"!=this.readyState||TWPHead.load(a,function(){console.timeEnd("ResourceBundle pb-r-identity")})};b.src="//www.washingtonpost.com/pb/resources/js/head.min.js";var c=document.getElementsByTagName("script")[0];c.parentNode.insertBefore(b,c)}else TWPHead&&TWPHead.load(a,
# function(){console.timeEnd("ResourceBundle pb-r-identity")})})(jQuery);</script> <script>console.timeEnd("exec-twp-global");</script> <script>window.NREUM||(NREUM={});
# __nr_require=function(a,f,e){function c(b){if(!f[b]){var d=f[b]={exports:{}};a[b][0].call(d.exports,function(d){return c(a[b][1][d]||d)},d,d.exports)}return f[b].exports}if("function"==typeof __nr_require)return __nr_require;for(var b=0;b<e.length;b++)c(e[b]);return c}({1:[function(a,f,e){function c(a){try{g.console&&console.log(a)}catch(b){}}var b;f=a("ee");a=a(19);var g={};try{b=localStorage.getItem("__nr_flags").split(","),console&&"function"==typeof console.log&&(g.console=!0,-1!==b.indexOf("dev")&&
# (g.dev=!0),-1!==b.indexOf("nr_dev")&&(g.nrDev=!0))}catch(d){}g.nrDev&&f.on("internal-error",function(a){c(a.stack)});g.dev&&f.on("fn-err",function(a,b,d){c(d.stack)});g.dev&&(c("NR AGENT IN DEVELOPMENT MODE"),c("flags: "+a(g,function(a,b){return a}).join(", ")))},{}],2:[function(a,f,e){function c(a,b,d){this.message=a||"Uncaught error with no additional information";this.sourceURL=b;this.line=d}var b=a("handle"),g=a(20);f=a("ee");var d=a("loader"),k=window.onerror,h=!1,l=0;d.features.err=!0;a(1);
# window.onerror=function(a,h,n,f,w){try{l?--l:b("err",[w||new c(a,h,n)])}catch(e){try{b("ierr",[e,d.now(),!0])}catch(r){}}return"function"==typeof k&&k.apply(this,g(arguments))};try{throw Error();}catch(n){"stack"in n&&(a(12),a(11),"addEventListener"in window&&a(6),d.xhrWrappable&&a(13),h=!0)}f.on("fn-start",function(a,b,d){h&&(l+=1)});f.on("fn-err",function(a,c,l){h&&(this.thrown=!0,b("err",[l,d.now()]))});f.on("fn-end",function(){h&&!this.thrown&&0<l&&--l});f.on("internal-error",function(a){b("ierr",
# [a,d.now(),!0])})},{}],3:[function(a,f,e){a("loader").features.ins=!0},{}],4:[function(a,f,e){function c(){y++;z=p.hash;this[k]=v.now()}function b(){y--;p.hash!==z&&g(0,!0);var a=v.now();this[l]=~~this[l]+a-this[k];this[h]=a}function g(a,b){m.emit("newURL",[""+p,b])}function d(a,b){a.on(b,function(){this[b]=v.now()})}var k="fn-start",h="fn-end",l="jsTime",n=window,p=n.location;if(n.addEventListener){f=a(9);e=a(10);var m=a(8),q=a(6),u=a(12),w=a(7),t=a(13),r=a("ee"),x=r.get("tracer");a(14);var v=a("loader");
# v.features.spa=!0;var z;a=n.addEventListener;var y=0;r.on(k,c);r.on("cb-start",c);r.on(h,b);r.on("cb-end",b);r.buffer([k,h,"xhr-done","xhr-resolved"]);q.buffer([k]);u.buffer(["setTimeout-end","clearTimeout-start",k]);t.buffer([k,"new-xhr","send-xhr-start"]);w.buffer(["fetch-start","fetch-done","fetch-body-start","fetch-body-end"]);m.buffer(["newURL"]);f.buffer([k]);e.buffer(["propagate","cb-start","cb-end","executor-err","resolve-start"]);x.buffer([k,"no-"+k]);d(t,"send-xhr-start");d(r,"xhr-resolved");
# d(r,"xhr-done");d(w,"fetch-start");d(w,"fetch-done");m.on("pushState-end",g);m.on("replaceState-end",g);a("hashchange",g,!0);a("load",g,!0);a("popstate",function(){g(0,1<y)},!0)}},{}],5:[function(a,f,e){function c(a){}if(window.performance&&window.performance.timing&&window.performance.getEntriesByType){f=a("ee");var b=a("handle");e=a(12);var g=a(11),d=a("loader");d.features.stn=!0;a(8);var k=NREUM.o.EV;f.on("fn-start",function(a,b){a[0]instanceof k&&(this.bstStart=d.now())});f.on("fn-end",function(a,
# c){var g=a[0];g instanceof k&&b("bst",[g,c,this.bstStart,d.now()])});e.on("fn-start",function(a,b,c){this.bstStart=d.now();this.bstType=c});e.on("fn-end",function(a,c){b("bstTimer",[c,this.bstStart,d.now(),this.bstType])});g.on("fn-start",function(){this.bstStart=d.now()});g.on("fn-end",function(a,c){b("bstTimer",[c,this.bstStart,d.now(),"requestAnimationFrame"])});f.on("pushState-start",function(a){this.time=d.now();this.startPath=location.pathname+location.hash});f.on("pushState-end",function(a){b("bstHist",
# [location.pathname+location.hash,this.startPath,this.time])});"addEventListener"in window.performance&&(window.performance.clearResourceTimings?window.performance.addEventListener("resourcetimingbufferfull",function(a){b("bstResource",[window.performance.getEntriesByType("resource")]);window.performance.clearResourceTimings()},!1):window.performance.addEventListener("webkitresourcetimingbufferfull",function(a){b("bstResource",[window.performance.getEntriesByType("resource")]);window.performance.webkitClearResourceTimings()},
# !1));document.addEventListener("scroll",c,{passive:!0});document.addEventListener("keypress",c,!1);document.addEventListener("click",c,!1)}},{}],6:[function(a,f,e){function c(a){for(;a&&!a.hasOwnProperty(h);)a=Object.getPrototypeOf(a);a&&b(a)}function b(a){d.inPlace(a,[h,l],"-",g)}function g(a,b){return a[1]}e=a("ee").get("events");var d=a(22)(e,!0),k=a("gos");a=XMLHttpRequest;var h="addEventListener",l="removeEventListener";f.exports=e;"getPrototypeOf"in Object?(c(document),c(window),c(a.prototype)):
# a.prototype.hasOwnProperty(h)&&(b(window),b(a.prototype));e.on(h+"-start",function(a,b){var c=a[1],g=k(c,"nr@wrapped",function(){var a={object:function(){if("function"==typeof c.handleEvent)return c.handleEvent.apply(c,arguments)},"function":c}[typeof c];return a?d(a,"fn-",null,a.name||"anonymous"):c});this.wrapped=a[1]=g});e.on(l+"-start",function(a){a[1]=this.wrapped||a[1]})},{}],7:[function(a,f,e){function c(a,c,d){var g=a[c];"function"==typeof g&&(a[c]=function(){var a=g.apply(this,arguments);
# return b.emit(d+"start",arguments,a),a.then(function(c){return b.emit(d+"end",[null,c],a),c},function(c){throw b.emit(d+"end",[c],a),c;})})}var b=a("ee").get("fetch");a=a(19);f.exports=b;f=window;e=["arrayBuffer","blob","json","text","formData"];var g=f.Request,d=f.Response,k=f.fetch;g&&d&&k&&(a(e,function(a,b){c(g.prototype,b,"fetch-body-");c(d.prototype,b,"fetch-body-")}),c(f,"fetch","fetch-"),b.on("fetch-end",function(a,c){var d=this;c?c.clone().arrayBuffer().then(function(a){d.rxSize=a.byteLength;
# b.emit("fetch-done",[null,c],d)}):b.emit("fetch-done",[a],d)}))},{}],8:[function(a,f,e){e=a("ee").get("history");a=a(22)(e);f.exports=e;a.inPlace(window.history,["pushState","replaceState"],"-")},{}],9:[function(a,f,e){e=a("ee").get("mutation");var c=a(22)(e),b=NREUM.o.MO;f.exports=e;b&&(window.MutationObserver=function(a){return this instanceof b?new b(c(a,"fn-")):b.apply(this,arguments)},MutationObserver.prototype=b.prototype)},{}],10:[function(a,f,e){function c(a){var b=g.context();a=d(a,"executor-",
# b);a=new h(a);return g.context(a).getCtx=function(){return b},g.emit("new-promise",[a,b],b),a}function b(a,b){return b}e=a(22);var g=a("ee").get("promise"),d=e(g),k=a(19),h=NREUM.o.PR;f.exports=g;h&&(window.Promise=c,["all","race"].forEach(function(a){var b=h[a];h[a]=function(c){function d(a){return function(){g.emit("propagate",[null,!e],f);e=e||!a}}var e=!1;k(c,function(b,c){Promise.resolve(c).then(d("all"===a),d(!1))});var f=b.apply(h,arguments);return h.resolve(f)}}),["resolve","reject"].forEach(function(a){var b=
# h[a];h[a]=function(a){var c=b.apply(h,arguments);return a!==c&&g.emit("propagate",[a,!0],c),c}}),h.prototype["catch"]=function(a){return this.then(null,a)},h.prototype=Object.create(h.prototype,{constructor:{value:c}}),k(Object.getOwnPropertyNames(h),function(a,b){try{c[b]=h[b]}catch(d){}}),g.on("executor-start",function(a){a[0]=d(a[0],"resolve-",this);a[1]=d(a[1],"resolve-",this)}),g.on("executor-err",function(a,b,c){a[1](c)}),d.inPlace(h.prototype,["then"],"then-",b),g.on("then-start",function(a,
# b){this.promise=b;a[0]=d(a[0],"cb-",this);a[1]=d(a[1],"cb-",this)}),g.on("then-end",function(a,b,c){this.nextPromise=c;g.emit("propagate",[this.promise,!0],c)}),g.on("cb-end",function(a,b,c){g.emit("propagate",[c,!0],this.nextPromise)}),g.on("propagate",function(a,b,c){this.getCtx&&!b||(this.getCtx=function(){if(a instanceof Promise)var b=g.context(a);return b&&b.getCtx?b.getCtx():this})}),c.toString=function(){return""+h})},{}],11:[function(a,f,e){e=a("ee").get("raf");var c=a(22)(e);f.exports=e;
# c.inPlace(window,["requestAnimationFrame","mozRequestAnimationFrame","webkitRequestAnimationFrame","msRequestAnimationFrame"],"raf-");e.on("raf-start",function(a){a[0]=c(a[0],"fn-")})},{}],12:[function(a,f,e){e=a("ee").get("timer");var c=a(22)(e);f.exports=e;c.inPlace(window,["setTimeout","setImmediate"],"setTimeout-");c.inPlace(window,["setInterval"],"setInterval-");c.inPlace(window,["clearTimeout","clearImmediate"],"clearTimeout-");e.on("setInterval-start",function(a,g,d){a[0]=c(a[0],"fn-",null,
# d)});e.on("setTimeout-start",function(a,g,d){this.method=d;this.timerDuration="number"==typeof a[1]?a[1]:0;a[0]=c(a[0],"fn-",this,d)})},{}],13:[function(a,f,e){function c(a,b){h.inPlace(b,["onreadystatechange"],"fn-",d)}function b(){var a=k.context(this);3<this.readyState&&!a.resolved&&(a.resolved=!0,k.emit("xhr-resolved",[],this));h.inPlace(this,p,"fn-",d)}function g(){for(var a=0;a<m.length;a++)c([],m[a]);m.length&&(m=[])}function d(a,b){return b}a(6);e=a("ee");var k=e.get("xhr"),h=a(22)(k);a=NREUM.o;
# var l=a.XHR,n=a.MO,p="onload onerror onabort onloadstart onloadend onprogress ontimeout".split(" "),m=[];f.exports=k;f=window.XMLHttpRequest=function(a){a=new l(a);try{k.emit("new-xhr",[a],a),a.addEventListener("readystatechange",b,!1)}catch(c){try{k.emit("internal-error",[c])}catch(d){}}return a};if(function(a,b){for(var c in a)b[c]=a[c];return b}(l,f),f.prototype=l.prototype,h.inPlace(f.prototype,["open","send"],"-xhr-",d),k.on("send-xhr-start",function(a,b){c(a,b);m.push(b);n&&(q=-q,u.data=q)}),
# k.on("open-xhr-start",c),n){var q=1,u=document.createTextNode(q);(new n(g)).observe(u,{characterData:!0})}else e.on("fn-end",function(a){a[0]&&"readystatechange"===a[0].type||g()})},{}],14:[function(a,f,e){function c(a){var c=this.params,d=this.metrics;if(!this.ended){this.ended=!0;for(var e=0;e<l;e++)a.removeEventListener(h[e],this.listener,!1);if(!c.aborted){if(d.duration=b.now()-this.startTime,4===a.readyState){c.status=a.status;var e=this.lastSize,f=a.responseType,e="json"===f&&null!==e?e:m("arraybuffer"===
# f||"blob"===f||"json"===f?a.response:a.responseText);(e&&(d.rxSize=e),this.sameOrigin)&&(e=a.getResponseHeader("X-NewRelic-App-Data"))&&(c.cat=e.split(", ").pop())}else c.status=0;d.cbTime=this.cbTime;k.emit("xhr-done",[a],a);g("xhr",[c,d,this.startTime])}}}var b=a("loader");if(b.xhrWrappable){var g=a("handle"),d=a(15),k=a("ee"),h=["load","error","abort","timeout"],l=h.length,n=a("id"),p=a(18),m=a(17),q=window.XMLHttpRequest;b.features.xhr=!0;a(13);k.on("new-xhr",function(a){var b=this;b.totalCbs=
# 0;b.called=0;b.cbTime=0;b.end=c;b.ended=!1;b.xhrGuids={};b.lastSize=null;p&&(34<p||10>p)||window.opera||a.addEventListener("progress",function(a){b.lastSize=a.loaded},!1)});k.on("open-xhr-start",function(a){this.params={method:a[0]};a=d(a[1]);var b=this.params;b.host=a.hostname+":"+a.port;b.pathname=a.pathname;this.sameOrigin=a.sameOrigin;this.metrics={}});k.on("open-xhr-end",function(a,b){"loader_config"in NREUM&&"xpid"in NREUM.loader_config&&this.sameOrigin&&b.setRequestHeader("X-NewRelic-ID",NREUM.loader_config.xpid)});
# k.on("send-xhr-start",function(a,c){var d=this.metrics,g=a[0],e=this;d&&g&&(g=m(g))&&(d.txSize=g);this.startTime=b.now();this.listener=function(a){try{"abort"===a.type&&(e.params.aborted=!0),("load"!==a.type||e.called===e.totalCbs&&(e.onloadCalled||"function"!=typeof c.onload))&&e.end(c)}catch(b){try{k.emit("internal-error",[b])}catch(d){}}};for(d=0;d<l;d++)c.addEventListener(h[d],this.listener,!1)});k.on("xhr-cb-time",function(a,b,c){this.cbTime+=a;b?this.onloadCalled=!0:this.called+=1;this.called!==
# this.totalCbs||!this.onloadCalled&&"function"==typeof c.onload||this.end(c)});k.on("xhr-load-added",function(a,b){var c=""+n(a)+!!b;this.xhrGuids&&!this.xhrGuids[c]&&(this.xhrGuids[c]=!0,this.totalCbs+=1)});k.on("xhr-load-removed",function(a,b){var c=""+n(a)+!!b;this.xhrGuids&&this.xhrGuids[c]&&(delete this.xhrGuids[c],--this.totalCbs)});k.on("addEventListener-end",function(a,b){b instanceof q&&"load"===a[0]&&k.emit("xhr-load-added",[a[1],a[2]],b)});k.on("removeEventListener-end",function(a,b){b instanceof
# q&&"load"===a[0]&&k.emit("xhr-load-removed",[a[1],a[2]],b)});k.on("fn-start",function(a,c,d){c instanceof q&&("onload"===d&&(this.onload=!0),("load"===(a[0]&&a[0].type)||this.onload)&&(this.xhrCbStart=b.now()))});k.on("fn-end",function(a,c){this.xhrCbStart&&k.emit("xhr-cb-time",[b.now()-this.xhrCbStart,this.onload,c],c)})}},{}],15:[function(a,f,e){f.exports=function(a){var b=document.createElement("a"),g=window.location,d={};b.href=a;d.port=b.port;a=b.href.split("://");!d.port&&a[1]&&(d.port=a[1].split("/")[0].split("@").pop().split(":")[1]);
# d.port&&"0"!==d.port||(d.port="https"===a[0]?"443":"80");d.hostname=b.hostname||g.hostname;d.pathname=b.pathname;d.protocol=a[0];"/"!==d.pathname.charAt(0)&&(d.pathname="/"+d.pathname);a=b.hostname===document.domain&&b.port===g.port;return d.sameOrigin=(!b.protocol||":"===b.protocol||b.protocol===g.protocol)&&(!b.hostname||a),d}},{}],16:[function(a,f,e){function c(){}function b(a,b,c){return function(){return g(a,[h.now()].concat(d(arguments)),b?null:this,c),b?void 0:this}}var g=a("handle");e=a(19);
# var d=a(20),k=a("ee").get("tracer"),h=a("loader"),l=NREUM;"undefined"==typeof window.newrelic&&(newrelic=l);e("setPageViewName setCustomAttribute setErrorHandler finished addToTrace inlineHit addRelease".split(" "),function(a,c){l[c]=b("api-"+c,!0,"api")});l.addPageAction=b("api-addPageAction",!0);l.setCurrentRouteName=b("api-routeName",!0);f.exports=newrelic;l.interaction=function(){return(new c).get()};var n=c.prototype={createTracer:function(a,b){var c={},d=this,e="function"==typeof b;return g("api-ixn-tracer",
# [h.now(),a,c],d),function(){if(k.emit((e?"":"no-")+"fn-start",[h.now(),d,e],c),e)try{return b.apply(this,arguments)}finally{k.emit("fn-end",[h.now()],c)}}}};e("setName setAttribute save ignore onEnd getContext end get".split(" "),function(a,c){n[c]=b("api-ixn-"+c)});newrelic.noticeError=function(a){"string"==typeof a&&(a=Error(a));g("err",[a,h.now()])}},{}],17:[function(a,f,e){f.exports=function(a){if("string"==typeof a&&a.length)return a.length;if("object"==typeof a){if("undefined"!=typeof ArrayBuffer&&
# a instanceof ArrayBuffer&&a.byteLength)return a.byteLength;if("undefined"!=typeof Blob&&a instanceof Blob&&a.size)return a.size;if(!("undefined"!=typeof FormData&&a instanceof FormData))try{return JSON.stringify(a).length}catch(b){}}}},{}],18:[function(a,f,e){a=0;(e=navigator.userAgent.match(/Firefox[\/\s](\d+\.\d+)/))&&(a=+e[1]);f.exports=a},{}],19:[function(a,f,e){var c=Object.prototype.hasOwnProperty;f.exports=function(a,e){var d=[],f="",h=0;for(f in a)c.call(a,f)&&(d[h]=e(f,a[f]),h+=1);return d}},
# {}],20:[function(a,f,e){f.exports=function(a,b,e){b||(b=0);"undefined"==typeof e&&(e=a?a.length:0);var d=-1;e=e-b||0;for(var f=Array(0>e?0:e);++d<e;)f[d]=a[b+d];return f}},{}],21:[function(a,f,e){f.exports={exists:"undefined"!=typeof window.performance&&window.performance.timing&&"undefined"!=typeof window.performance.timing.navigationStart}},{}],22:[function(a,f,e){function c(a){return!(a&&a instanceof Function&&a.apply&&!a[d])}var b=a("ee"),g=a(20),d="nr@original",k=Object.prototype.hasOwnProperty,
# h=!1;f.exports=function(a,e){function f(a,b,e,k){function h(){var c,d,f,l;try{d=this,c=g(arguments),f="function"==typeof e?e(c,d):e||{}}catch(n){u([n,"",[c,d,k],f])}m(b+"start",[c,d,k],f);try{return l=a.apply(d,c)}catch(v){throw m(b+"err",[c,d,v],f),v;}finally{m(b+"end",[c,d,l],f)}}return c(a)?a:(b||(b=""),h[d]=a,q(a,h),h)}function m(b,c,d){if(!h||e){var f=h;h=!0;try{a.emit(b,c,d,e)}catch(g){u([g,b,c,d])}h=f}}function q(a,b){if(Object.defineProperty&&Object.keys)try{return Object.keys(a).forEach(function(c){Object.defineProperty(b,
# c,{get:function(){return a[c]},set:function(b){return a[c]=b,b}})}),b}catch(c){u([c])}for(var d in a)k.call(a,d)&&(b[d]=a[d]);return b}function u(b){try{a.emit("internal-error",b)}catch(c){}}return a||(a=b),f.inPlace=function(a,b,d,e){d||(d="");var g,k,h,l="-"===d.charAt(0);for(h=0;h<b.length;h++)k=b[h],g=a[k],c(g)||(a[k]=f(g,l?k+d:d,e,k))},f.flag=d,f}},{}],ee:[function(a,f,e){function c(){}function b(a){function e(a){return a&&a instanceof c?a:a?h(a,k,g):g()}function f(b,c,d,g){if(!m.aborted||g){a&&
# a(b,c,d);d=e(d);g=t(b);for(var k=g.length,h=0;h<k;h++)g[h].apply(d,c);g=n[x[b]];return g&&g.push([v,b,c,d]),d}}function t(a){return r[a]||[]}var r={},x={},v={on:function(a,b){r[a]=t(a).concat(b)},emit:f,get:function(a){return p[a]=p[a]||b(f)},listeners:t,context:e,buffer:function(a,b){l(a,function(a,c){b=b||"feature";x[c]=b;b in n||(n[b]=[])})},abort:d,aborted:!1};return v}function g(){return new c}function d(){(n.api||n.feature)&&(m.aborted=!0,n=m.backlog={})}var k="nr@context",h=a("gos"),l=a(19),
# n={},p={},m=f.exports=b();m.backlog=n},{}],gos:[function(a,f,e){var c=Object.prototype.hasOwnProperty;f.exports=function(a,e,d){if(c.call(a,e))return a[e];d=d();if(Object.defineProperty&&Object.keys)try{return Object.defineProperty(a,e,{value:d,writable:!0,enumerable:!1}),d}catch(f){}return a[e]=d,d}},{}],handle:[function(a,f,e){function c(a,c,e,f){b.buffer([a],f);b.emit(a,c,e)}var b=a("ee").get("handle");f.exports=c;c.ee=b},{}],id:[function(a,f,e){var c=1,b=a("gos");f.exports=function(a){var d=typeof a;
# return!a||"object"!==d&&"function"!==d?-1:a===window?0:b(a,"nr@id",function(){return c++})}},{}],loader:[function(a,f,e){function c(){if(!r++){var a=t.info=NREUM.info,b=p.getElementsByTagName("script")[0];if(setTimeout(n.abort,3E4),!(a&&a.licenseKey&&a.applicationID&&b))return n.abort();l(w,function(b,c){a[b]||(a[b]=c)});h("mark",["onload",d()+t.offset],null,"api");var c=p.createElement("script");c.src="https://"+a.agent;b.parentNode.insertBefore(c,b)}}function b(){"complete"===p.readyState&&g()}
# function g(){h("mark",["domContent",d()+t.offset],null,"api")}function d(){return x.exists&&performance.now?Math.round(performance.now()):(k=Math.max((new Date).getTime(),k))-t.offset}var k=(new Date).getTime(),h=a("handle"),l=a(19),n=a("ee");e=window;var p=e.document,m=e.XMLHttpRequest,q=m&&m.prototype;NREUM.o={ST:setTimeout,CT:clearTimeout,XHR:m,REQ:e.Request,EV:e.Event,PR:e.Promise,MO:e.MutationObserver};var u=""+location,w={beacon:"bam.nr-data.net",errorBeacon:"bam.nr-data.net",agent:"js-agent.newrelic.com/nr-spa-1026.min.js"},
# m=m&&q&&q.addEventListener&&!/CriOS/.test(navigator.userAgent),t=f.exports={offset:k,now:d,origin:u,features:{},xhrWrappable:m};a(16);p.addEventListener?(p.addEventListener("DOMContentLoaded",g,!1),e.addEventListener("load",c,!1)):(p.attachEvent("onreadystatechange",b),e.attachEvent("onload",c));h("mark",["firstbyte",k],null,"api");var r=0,x=a(21)},{}]},{},["loader",2,14,5,3,4]);NREUM.info={beacon:"bam.nr-data.net",errorBeacon:"bam.nr-data.net",licenseKey:"33dbaac1f2",applicationID:"33762581",sa:1};</script> <script>"object"==typeof newrelic&&(newrelic.setCustomAttribute("site","www.washingtonpost.com"),newrelic.setCustomAttribute("rawUserAgent",navigator.userAgent));</script> </head> <body class="pb-theme-normal pb-full-fluid"> <div class="pub_300x250 pub_300x250m pub_728x90 text-ad textAd text_ad text_ads text-ads text-ad-links" id="wp-adb-c" style="width: 1px !important; height: 1px !important; position: absolute !important; left: -10000px !important; top: -1000px !important;"></div> <div id="pb-f-a"></div> <div class="" id="pb-root"><section class="col-xs-12 layout" id="top-furniture"> <div class="pb-container"> <div class="moat-trackable pb-f-theme-normal pb-f-dehydrate-false pb-1 pb-feature pb-layout-item pb-f-page-push-notifications" data-chain-name="no-name" data-feature-id="page/push-notifications" data-feature-name="no-name" data-pb-fingerprint="0fIGqM7kWpl" id="f0S0MhfLti3loq" moat-id="page/push-notifications|powerpost"> <div class="notifications-container hidden"> <div class="pull-right notify-ic"> <i aria-hidden="true" class="fa fa-bell-o"></i> <span class="notif-number hide">2</span> </div> <div class="clear"> </div> <div class="notification-items hide"> <div class="notifications-top-arrow"></div> <div class="notifications-list"> </div> <div class="notifications-controll"> <p class="notify-txt">Desktop notifications are on   | <a class="turn-off" href="">Turn off</a> </p> </div> </div> <div class="permission-request hide"> <div class="notifications-top-arrow"></div> <p class="headline">Get breaking news alerts from <span class="wp-txt"> The Washington Post </span></p> <div class="permission-default"> <p class="notify-txt">Turn on desktop notifications?</p> <div class="actions-container"> <span class="notify-action yes">Yes</span> <span class="notify-action not-now">Not now</span> </div> </div> <div class="permission-denied hide"> <p class="notify-txt">It looks like you've previously blocked notifications. Please update your browser permissions to allow them.</p> <img class="permission-denied-img" src="/pb/resources/img/push_notifications/notification_denied_v1.png"/> </div> </div> </div> </div> </div> <div class="moat-trackable pb-f-theme-normal pb-f-dehydrate-false full pb-feature pb-layout-item pb-f-page-header-v2" data-chain-name="no-name" data-feature-id="page/header-v2" data-feature-name="no-name" data-pb-fingerprint="0fSlubXsip7" id="f0Q1a5KLti3loq" moat-id="page/header-v2|powerpost"> <!--[if IE 9]><style>#main-sections-nav.subNavigation{width:475px !important}#main-sections-nav{left:-250px !important;width:315px !important}#main-sections-nav-inner{position:absolute !important}#main-sections-nav.subNavigation #main-sections-nav-inner{width:550px !important;overflow-x:hidden !important}#main-sections-nav.subNavigation{width:470px !important}</style><![endif]--> <!--[if IE 9]><div id="page" class="ie ie9 "><![endif]--> <!--[if IE 8]><div id="page" class="ie ie8 "><![endif]--> <!--[if !IE]><!--> <div class="nie " id="page"> <!--<![endif]--> <header class="site-header fixed " id="wp-header"> <nav class="top-nav" id="nav-bar" role="navigation"> <div class=" nav-display-show " id="logo-in-nav" itemprop="publisher" itemscope="" itemtype="https://schema.org/Organization"> <a class="wp-logo-link" href="https://www.washingtonpost.com" itemprop="logo" itemscope="" itemtype="https://schema.org/ImageObject"> <img alt="The Washington Post" class="main-logo" src="https://www.washingtonpost.com/pb/resources/img/thewashingt ...
# (function(d){if(function(){var R="undefined"===typeof IXC_208_6842601999681979||"undefined"===typeof IXC_208_6842601999681979.CanRun||"_208_6842601999681979"!==IXC_208_6842601999681979._208_6842601999681979||IXC_208_6842601999681979.CanRun("abd");if(R)try{(d.IXC_208_6842601999681979=d.IXC_208_6842601999681979||{})._208_6842601999681979="_208_6842601999681979",d[atob("SU5TVEFSVA==")+"_TARGET_NAME"]="abd",d[atob("STExQw==")]=d[atob("STExQw==")]||{}}catch(g){console.error(g)}else{var Y="abd"!==d[atob("SU5TVEFSVA==")+
# "_TARGET_NAME"],L="double nanovisor injection: abd after "+d[atob("SU5TVEFSVA==")+"_TARGET_NAME"];Y&&console.log(L);"function"!==typeof d[atob("SU5TVEFSVA==")].Init&&(d[atob("SU5TVEFSVA==")].Init=function(){Y&&console.error("ignored Init call after "+L)})}return R}()){(function(){function R(){var b=d.googletag;if((b=b&&b.pubads&&"function"===typeof b.pubads&&b.pubads())&&b.addEventListener&&"function"===typeof b.addEventListener)try{b.addEventListener("slotRenderEnded",function(a){var c=a.slot&&a.slot.getSlotElementId();
# a.isEmpty||(Z[c]=!0);Qa.b(c,a.isEmpty)}),b.addEventListener("slotVisibilityChanged",function(a){a=a.slot&&a.slot.getSlotElementId();Z[a]&&Ra.b(a)}),b.addEventListener("slotOnload",function(a){a=a.slot&&a.slot.getSlotElementId();Z[a]&&Sa.b(a)}),b.addEventListener("impressionViewable",function(a){a=a.slot&&a.slot.getSlotElementId();Z[a]&&Ta.b(a)}),d.clearInterval(Ua)}catch(a){}}function Y(b,a){return ta(b,a,L,{H:function(a,b){return a.concat(b)}})}function L(b,a){return"object"!==typeof a||Array.isArray(a)?
# a:ta(a,b,L)}function g(b){return b.split("").filter(function(a,c){return 0===c%2}).reverse().join("")}function l(b,a){function c(){this.constructor=b}cc(b,a);b.prototype=null===a?Object.create(a):(c.prototype=a.prototype,new c)}function z(){return 1===A.c}function Va(){return 4===A.c}function aa(){return 2===A.c}function Wa(){return 3===A.c}function Xa(){return 5===A.c}function ba(b){M=new ua(b);A=M.X;S=M.ka;return M}function Ya(){for(var b=[],a=1;9>=a;a++)b[a]=N["$"+a];return b}function Za(b){for(var a=
# "",c="",e=1;b&&9>=e;e++)b[e]?(b[e]=b[e].replace(/[-[\]{}()*+?.,\\^$|#\s]/g,"\\$&"),a+="("+b[e]+")",c+=""+b[e]):a+="()";c.match(a)}function O(b){return"string"===typeof b&&0<b.length?b:null}function va(b,a){if(!b&&(console.error(a),(b=[],0<b.length)&&console.log(b),$a))throw a;}function ab(b){var a="";try{a=b.location.protocol}catch(c){a="cross"}return a}function ta(b,a,c,e){if(!b)return a;if(a)for(var f=Object.keys(a),k=f.length-1;0<=k;--k){var d=f[k],n=a[d],g=b[d],n="undefined"===typeof g?n:(e&&
# e[d]||c)(g,n);b[d]=n}return b}function cb(b){var a;void 0===a&&(a=dc);var c=new a.ra;b.onload&&(c.onload=function(){return b.onload(new wa(c,b))});b.onerror&&(c.onerror=function(){return b.onload(new wa(c,b))});c.withCredentials=!!b.credentials;a.$c.call(c,b.method,b.url,!1!==b.async);if(b.Ca)for(var e=0;e<b.Ca.length;e++)c.setRequestHeader(b.Ca[e].D,b.Ca[e].be);var e=b.body&&JSON.stringify(b.body),f=!1===b.async;try{a.sd.call(c,e)}catch(k){if(f&&b.onerror)b.onerror(null)}f&&new wa(c,b)}function db(b){return function(a){function c(){return null!==
# a&&a.apply(this,arguments)||this}l(c,a);c.prototype.fa=function(){throw Error("Method not implemented.");};return c}(b)}function eb(b){return function(a){function c(){var c=null!==a&&a.apply(this,arguments)||this;c.Xc=new ca;return c}l(c,a);return c}(b)}function fb(b){b.pa.Qc();gb=b}function B(b,a){b=b.split(".");for(var c=d||{},e,f=0;f<b.length-1;++f){e=b[f];if(!c)return;var k=c[e]||{};try{c[e]=k}catch(bb){}c=k}e=b[b.length-1];if(c){va(!!e,"In Export, name not defined");try{c[e]=a}catch(bb){}}}function ec(b){b=
# b.split(".");for(var a=d,c,e=0;a&&e<b.length-1;++e)if(c=b[e],a=a[c],!a)return;c=b[b.length-1];va(!!a&&!!c,"In Deport, obj or name not defined");try{var f=Object.getOwnPropertyDescriptor(a,c);f&&f.writable&&delete a[c]||(a[c]=void 0)}catch(k){}}function xa(){return d.document.currentScript||d.document.scripts[document.scripts.length-1]}function fc(){if(y&&F&&(y.nextSibling===F||y===F))for(var b=F.nextSibling,a=y;a&&a!=b;){var c=a,a=a.nextSibling;c.parentNode&&c.parentNode.removeChild&&c.parentNode.removeChild(c)}ec(da);
# B(da+".Init",function(){});F=y=null}function p(b,a,c){var e={};e.Type=b;e[w]=a;c&&(e[hb]=c);return e}function T(b,a,c){try{Object.defineProperty(b,a,c)}catch(e){}}function ea(b){var a=typeof b;if(b&&("object"===a||"function"===a)&&!gc.call(b,"__ext")){if(b instanceof NodeList||b instanceof HTMLCollection){for(var a=b.length,c=0;c<a;c++)ea(b[c]);return b}a=void 0;c=b.nodeType,1===c&&(a=ya[b.nodeName]),a||(a=ib[c]),a||(a=b.__pext);a&&(c={ce:{},gd:a,Ma:hc++},jb.value=c,Object.defineProperty(b,"__ext",
# jb),a.wb(b))}return b}function fa(b,a){var c=b.__ext;c||(ea(b),c=b.__ext);return(b=c)&&b.gd.Dc(a)}function ic(b,a){for(var c=Object.getOwnPropertyNames(b),e=0,f=c.length;e<f;++e){var k=c[e];if(!(k in a)){var d=Object.getOwnPropertyDescriptor(b,k);try{Object.defineProperty(a,k,d)}catch(n){}}}(c=b.prototype)&&(a.prototype=c);if(b=b.name)try{Object.defineProperty(a,"name",{value:b})}catch(n){}}function jc(b){b.N.ya(function(){var a=fa(this,b.D);return a?a.Nd(this):b.N.G.call(this)});b.Set.ya(function(a){var c=
# fa(this,b.D);c?c.Set(this,a,!0,!1):b.Set.G.call(this,a);return a})}function kb(b,a,c){var e=Object.getOwnPropertyDescriptor(b,a),f=e&&e.get,k=e&&e.set,d=e&&e.value;f||k?Object.defineProperty(b,a,{get:f,set:function(a){d=a;c(d);k.apply(this,arguments)},enumerable:e.enumerable,configurable:!0}):Object.defineProperty(b,a,{get:function(){return d},set:function(a){d=a;c(d)},enumerable:e&&e.enumerable||!0,configurable:!0})}function kc(){function b(b){Array.isArray(b)&&!a(b)&&b.push(c)}function a(a){for(var b=
# !1,e=0;e<a.length;e++)if(a[e]===c){b=!0;break}return b}function c(){var a=d.googletag.display,c=[];d.googletag.display=function(b){b?(c.push({id:b}),lc.push(b),lb.b([b])):c.push({id:"unknown"});e++;a.apply(this,arguments)}}var e=0,f=d.googletag||{};d.googletag=f;f.cmd=f.cmd||[];f.cmd.push(c);kb(d,"googletag",function(e){Array.isArray(e.cmd)&&!a(e.cmd)&&e.cmd.push(c);kb(e,"cmd",b)})}function mc(){d.pbjs=d.pbjs||{};d.pbjs.que=d.pbjs.que||[];d.pbjs.que.push(function(){d.pbjs.onEvent("bidResponse",function(b){mb.push({SlotId:b.adUnitCode,
# ExchangeName:b.bidder,CPM:b.cpm,ResponseTime:b.timeToRespond})});d.pbjs.onEvent("auctionInit",function(){nb=!0})})}function za(b){try{var a=d[b];a.setItem("TEST","TEST");a.removeItem("TEST");return!0}catch(c){return!1}}function Aa(b){var a=document.cookie,c="";if(a){var e=a.indexOf(b);-1<e&&(a=a.slice(e),b=b.replace(/[.]/g,"[.]").replace(/\$/g,"[$]"),(b=(new RegExp("(?:\\b"+b+"\\b\\s*=\\s*)([^;]*);?")).exec(a))&&b[1]&&(c=b[1]))}return c}function Ba(){var b={};try{if(za(ob)){var a=sessionStorage._208_6842601999681979;
# a&&(b=JSON.parse(a))}}catch(c){}return b}function nc(b){oc.za.Set.kd(function(a){for(var c=0;c<b.a.H.length;c++)if(b.a.H[c].test(a)){this.addEventListener("error",function(){pc.b(a);a&&(pb[a]=!0)});this.addEventListener("load",function(){a&&(Ca[a]=!0)});break}})}function qc(){return new ga(function(b){function a(a){var e=!1;"load"===a.type?e=!1:"error"===a.type&&(e=!0);b(p(rc,e,a.currentTarget.src));c&&(a=a.target)&&a.parentNode&&a.parentNode.removeChild(a)}var c=4===A.c&&3===S.c,e=document.createElement("img");
# e.onload=a;e.onerror=a;var f=Math.floor(Math.random()*U.length);e.src=U[f]+"?"+qb[Math.floor(Math.random()*qb.length)];c&&document.body.appendChild(e);1<U.length&&U.splice(f,1)})}function Da(b,a,c,e){return new ga(function(f){var d=sc,g=Va();if(z()||g||aa()){var n;g&&(n=setTimeout(function(){f(p(d,!1,"Timed out on error"))},500));var l=!1,h=function(a){if(!l){l=!0;g&&clearTimeout(n);var c=!1;"load"===a.type?c=!1:"error"===a.type&&(c=!0);f(p(d,c,a.currentTarget.href));m&&m.parentNode&&m.parentNode.removeChild(m)}},
# m=document.createElement("link");m.onload=h;m.onerror=h;m.rel=e||aa()?"prefetch":"preload";m.as="track";a&&m.setAttribute("crossorigin","anonymous");c&&m.setAttribute("referrerpolicy","no-referrer");h=Math.floor(Math.random()*b.length);m.href=b[h];C&&C.parentNode&&C.parentNode.insertBefore(m,C);1<b.length&&b.splice(h,1)}else f(p(d,!1,"Neither Chrome nor Safari"))})}function uc(){return new ga(function(b){var a=document.createElement("iframe");a.src=d.atob("Ly90cGMuZ29vZ2xlc3luZGljYXRpb24uY29tL3NhZmVmcmFtZS8=")+
# d.atob("MS0wLTU=")+d.atob("L2h0bWwvY29udGFpbmVyLmh0bWw=");a.style.height="1px";a.style.width="1px";a.style.left="-555px";a.style.top="-555px";a.style.display="block";a.scrolling="no";a.frameBorder="0";var c=d.atob("PHNjcmlwdD53aW5kb3cucGFyZW50ICYmIHdpbmRvdy5wYXJlbnQucG9zdE1lc3NhZ2UoIg==")+d.atob("aTEwY09L")+d.atob("IiwgICIqIik8L3NjcmlwdD4="),e=setTimeout(function(){b(p(D,!0,"Disabled"));clearTimeout(e);a.parentNode&&a.parentNode.removeChild(a)},5E3),f=rb();a.name=d.atob("MS0wLTU=")+";"+c.length+";"+
# c;d.addEventListener("message",function(c){c=c.data;"string"===typeof c&&0===c.lastIndexOf(d.atob("aTEwY09L"),d.atob("aTEwY09L").length+1)&&(b(p(D,!1,String(rb()-f))),clearTimeout(e),a.parentNode&&a.parentNode.removeChild(a))},!1);C&&C.parentNode&&C.parentNode.insertBefore(a,C)})}function vc(){return new ga(function(b){var a=sb[Math.floor(Math.random()*sb.length)],c=document.createElement(a[0]);c.id=a[1];c.style.width="1px";c.style.height="1px";c.style.top="-555px";c.style.left="-555px";c.style.display=
# "block";var e=setInterval(function(){document&&document.body&&(document.body.appendChild(c),clearInterval(e),setTimeout(function(){var a=getComputedStyle(c),e,d=!1;if("none"===a.display||(e=a.getPropertyValue("-moz-binding"))&&-1!==e.indexOf("abp-elemhidehit"))d=!0;b(p(wc,d));c&&c.parentNode&&c.parentNode.removeChild(c)},200))},10)})}function xc(b){return b[w]||"BFRAME"===b.Type||"ADB"===b.Type||"ADBSTATS"==b.Type}function ha(b,a){try{var c=[],c=a.Results&&(a[w]?a.Results:a.Results.filter(xc));ia[w]&&
# c.push(ia);var e={adbType:[a[w]?"PRESENT":"NOT"],otherData:JSON.stringify(c),clientIpAddr:"",userAgent:navigator.userAgent,pageUrl:d.location.href,detectionTime:a[ja]},f={data_stream_type:"adb",json_data:JSON.stringify(e),generated_timestamp_msec:Date.now()};tb.Wa.G?tb.Wa.G.call(navigator,b,JSON.stringify(f)):cb({method:"POST",url:b,body:f,async:!0,onload:void 0,onerror:void 0,onchange:void 0})}catch(k){}}function Ea(b,a){B(ka+"."+b,a);B(Fa+"."+b,a)}function ub(b){Ga?b(Ga):vb.push(b)}function yc(b){Ga=
# b;var a=!0;vb.forEach(function(c){a=c(b)&&a});return a}function zc(){"d3d3Lndhc2hpbmd0b25wb3N0LmNvbQ=="===d.btoa(d.location.hostname)&&ub(function(b){if(b[w])try{if(d.localStorage.setItem("__iabcd","true"),"true"===d.localStorage.getItem("__iabcr")||-1<document.cookie.indexOf("__iabcr=true"))return!0}catch(a){}else try{d.localStorage.removeItem("__iabcd")}catch(a){}return!1})}function la(b){return document[b]&&""===document[b].name?!0:!1}var Fa=g("C11110I6"),ka=g("C40417I2"),da=g("T0R5A1T3S4N4I9"),
# ma=g("r4e2n3e5t4s8i0L8t8n1e5v3E3d7d4A8d6e4h2c3t5a4P8"),na=g("r6o9r3r1E3n8O0d6e9h4c8t3a4P3"),wb=g("=0=6A4d5v595m4U73196G9Z1h3h928c9"),P=g("00V520Z1"),Ac=g("00V124a4j59420U0i4V627V7"),G=g("E8B1U8O2Y7");g("B4U5O0Y6");g("P2B4D3A9");var Q=g("B5D4A3"),xb=g("S9T1A1T3S8B2D1A5");g("G8D3A7");g("P4C3X4E6");var Bc=g("X8L7O8V9"),t=g("E4N2O2N3"),H=g("E1V9A6R9B6"),Cc=g("d6e9r4i8f5_7d2a3o3l1n2o0_5e0l7g8o6o9g4"),Dc=g("r8o3t8a2g6i6v3a3N0"),Ec=g("k2c8a4r2T3t1o5N5o8d1"),Fc=g("e2d2o0c3 1e6v5i3t3a2n6"),Gc=g("k3c0a7b6l8l4a7C3d6b5A2r4e3t6s0i7g3e0R7"),
# ...
# c&&f.push(c)}),f.join(y)};a.prototype.$plugins.getTrackVar=a.prototype.$plugins.toTrackVar;a.prototype._deregisterVariant=function(b){b=f(b);this._removeLocalItem(b.name);this._removeLocalItem(b.visit);this._removeLocalItem(b.blacklisted);this._removeLocalItem(b.compute);this._removeLocalItem(b.hash);this._removeLocalItem(b.phash)};a.prototype._detectLocalStorage=function(){try{return this._setLocalItem("_adwi_","_adwi_"),this._removeLocalItem("_adwi_"),!0}catch(b){return!1}};a.prototype._isOptOut=
# function(){return"yes"==this._getLocalItem("Dw__OO")};a.prototype._removeLocalItem=function(b){b=[b,this.id()].join("|");localStorage.removeItem(b)};a.prototype._getLocalItem=function(b){b=[b,this.id()].join("|");try{return localStorage.getItem(b)}catch(a){return null}};a.prototype._setLocalItem=function(b,a){var d=[b,this.id()].join("|");this._getLocalItem(d)&&this._removeLocalItem(d);try{return localStorage.setItem(d,a)}catch(c){return r}};a.prototype.getTest=function(b){return this._testData[b]||
# new this.Test({},this)};a.prototype.visitor=function(){return this._visitor};a.prototype.Visitor=function(b,f){this.has=function(b){function e(b){b=b instanceof a.prototype.Variant?b.getTest():b||{};return"registered"==b.state||"persisted"==b.state}var g;return f&&b instanceof f?c.each(b.toArray(),function(b,a){if(!(g=e(a)))return!1}):g=e(b),g}};a.prototype.Variant=function(b,a){var c=b||{};this.nocollect=!c.collect;this.historic=c.historic||!1;this.run=c.run||!1;var e=c.variation||{};this.getTest=
# function(){return a.getTest(c.name)};this.name=e.name||"";this.trackvars=e.track||[];this.customOptions=e.customOptions||{}};a.prototype.Test=function(b,a){var c=b.name||"",e=f(c),g=b.increment||0,k=b.variations||[],m=b["x-persist"]||!1,l=b.blacklist&&b.blacklist.referrers||[],p="yes"==a._getLocalItem(e.blacklisted),h=t(b,"segment");this._originalData=b;this.data=function(b,a){if(a==r)return this._originalData[b];this._originalData[b]=a};this.getToolkit=function(){return a};var u=D(h);this.segments=
# h?u.match:[];h=!!h&&u.value;p||a._getLocalItem(e.blacklisted)||(p=a._isBlacklisted(l)||!h,a._setLocalItem(e.blacklisted,p?"yes":"no"));e=!!k.length;g=k.length&&new a.Variant(a._registerVariant(c,k,p,g,h,m),a);this.name=c;e&&b.active&&!g.nocollect&&(this.variation=g);k=e&&b.active?b.defaultTrack:[];p&&Array.prototype.push.apply(k,b.blacklist?b.blacklist.track:[]);(k.length&&g.nocollect||!e||!g||!h)&&(this.variation=new a.Variant({name:c,variation:{track:h?k:[]}},a));e&&g&&h?g&&g.run?this.state="registered":
# this.state="persisted":(a._deregisterVariant(c),this.state="deregistered")};a.prototype._registerVariant=function(b,a,d,e,g,k){var h=f(b);e=k?w(b,[],!1,e):w(b,a,d,e);var m=k?this._getLocalItem(h.phash):this._getLocalItem(h.hash),l=this._getLocalItem(h.name);k="yes"==this._getLocalItem(h.visit);var p="yes"==this._getLocalItem(h.compute),t=function(a,b){a=parseFloat(a.customOptions.target);b=parseFloat(b.customOptions.target);return a<b?-1:a>b?1:0},r=u[this.id()],q=x(a,"name",l);if(g=!(!g||(p||d||"string"==
# typeof l||q)&&(!p||e==m)))if(r._mset&&r._mset[b])c.each(a,function(a,c){r._mset[b][c.name]&&(q=c)});else{a.sort(t);var B=[],z=0,A=0;c.each(a,function(a,b){var c=b.customOptions&&b.customOptions.target;if(c){c=parseFloat(c)/100;z+=c;var d={value:[A,z]};A+=c;B.push(d)}});var C=Math.random(0,1);c.each(B,function(a,b){C>=b.value[0]&&C<=b.value[1]&&(l=a)});q=a[l]}q?this._setLocalItem(h.name,q.name):this._setLocalItem(h.name,"_default");this._setLocalItem(h.visit,"yes");this._setLocalItem(h.compute,"yes");
# this._setLocalItem(h.hash,e);this._setLocalItem(h.phash,e);a=q&&(!d||k)&&{name:b,variation:q,collect:!0};return a||(a={name:b}),a.run=g,a};a.prototype._isBlacklisted=function(a){var f;a=a||[];return this._ignoreBlacklist||c.each(a,function(a,b){var c=new RegExp("^(http://)?(www\\.)?"+b.replace(/\./g,"\\.").replace(/\-/g,"\\-"),"gi");return!(f=!b&&!document.referrer||0<(b&&document.referrer.match(c)||[]).length)}),f};m("darwin-toolkit:v2.0.0",function(){return!0});l._dw.push=function(a){u[a[0]]?(u[a[0]]._dispatches[a[1]]&&
# a[2]&&a[2](u[a[0]]),u[a[0]]._handlers.push(a.slice(1,a.length))):(p[a[0]]||(p[a[0]]=[]),p[a[0]].push(a.slice(1,a.length)))};l._dw})(VisitorSegment,this);(function(m){m=new m("global");m.config({trackValueDelimiter:",",deferSegments:!0,collections:[{name:"recommendation",disabled:!1,tests:[{name:"recommendation-influencersexperiments",active:!0,"x-persist":!0,"x-status":"1",increment:0,segment:{},_token:"e3d87a",variations:[{customOptions:{target:"50"},name:"influencers",track:[{name:"list1",dynamic:!1,
# value:"recommendation-influencersexperiments:influencers"},{name:"prop56",dynamic:!1,value:"recommendation-influencersexperiments:influencers"},{name:"list1",dynamic:!1,value:"recommendation-influencersexperiments-e3d87a"},{name:"prop56",dynamic:!1,value:"recommendation-influencersexperiments-e3d87a"}]}],defaultTrack:[{name:"list1",dynamic:!1,value:"recommendation-influencersexperiments:default"},{name:"prop56",dynamic:!1,value:"recommendation-influencersexperiments:default"},{name:"list1",dynamic:!1,
# value:"recommendation-influencersexperiments-e3d87a"},{name:"prop56",dynamic:!1,value:"recommendation-influencersexperiments-e3d87a"}]}]},{name:"article",disabled:!1,tests:[{name:"article-breakingnews",active:!1,"x-persist":!0,"x-status":"1","x-linked":"0",increment:0,segment:{desktop:!0},_token:"3d7545",variations:[{customOptions:{target:"34"},name:"nobreakingnews",track:[{name:"list1",dynamic:!1,value:"article-breakingnews:nobreakingnews"},{name:"prop56",dynamic:!1,value:"article-breakingnews:nobreakingnews"},
# {name:"list1",dynamic:!1,value:"article-breakingnews-3d7545"},{name:"prop56",dynamic:!1,value:"article-breakingnews-3d7545"}]},{customOptions:{target:"33"},name:"sectionbreakingnews",track:[{name:"list1",dynamic:!1,value:"article-breakingnews:sectionbreakingnews"},{name:"prop56",dynamic:!1,value:"article-breakingnews:sectionbreakingnews"},{name:"list1",dynamic:!1,value:"article-breakingnews-3d7545"},{name:"prop56",dynamic:!1,value:"article-breakingnews-3d7545"}]},{customOptions:{target:"33"},name:"allbreakingnews",
# track:[{name:"list1",dynamic:!1,value:"article-breakingnews:allbreakingnews"},{name:"prop56",dynamic:!1,value:"article-breakingnews:allbreakingnews"},{name:"list1",dynamic:!1,value:"article-breakingnews-3d7545"},{name:"prop56",dynamic:!1,value:"article-breakingnews-3d7545"}]}],defaultTrack:[{name:"list1",dynamic:!1,value:"article-breakingnews:default"},{name:"prop56",dynamic:!1,value:"article-breakingnews:default"},{name:"list1",dynamic:!1,value:"article-breakingnews-3d7545"},{name:"prop56",dynamic:!1,
# value:"article-breakingnews-3d7545"}]},{name:"article-oneClickNL",active:!0,"x-persist":!0,"x-status":"1","x-linked":"0",increment:0,segment:{"not logged in mobile":!0},_token:"60e020",variations:[{customOptions:{target:"25"},name:"visual",track:[{name:"list1",dynamic:!1,value:"article-oneClickNL:visual"},{name:"prop56",dynamic:!1,value:"article-oneClickNL:visual"},{name:"list1",dynamic:!1,value:"article-oneClickNL-60e020"},{name:"prop56",dynamic:!1,value:"article-oneClickNL-60e020"}]},{customOptions:{target:"25"},
# name:"oneClick",track:[{name:"list1",dynamic:!1,value:"article-oneClickNL:oneClick"},{name:"prop56",dynamic:!1,value:"article-oneClickNL:oneClick"},{name:"list1",dynamic:!1,value:"article-oneClickNL-60e020"},{name:"prop56",dynamic:!1,value:"article-oneClickNL-60e020"}]},{customOptions:{target:"25"},name:"oneClickAlt",track:[{name:"list1",dynamic:!1,value:"article-oneClickNL:oneClickAlt"},{name:"prop56",dynamic:!1,value:"article-oneClickNL:oneClickAlt"},{name:"list1",dynamic:!1,value:"article-oneClickNL-60e020"},
# {name:"prop56",dynamic:!1,value:"article-oneClickNL-60e020"}]}],defaultTrack:[{name:"list1",dynamic:!1,value:"article-oneClickNL:default"},{name:"prop56",dynamic:!1,value:"article-oneClickNL:default"},{name:"list1",dynamic:!1,value:"article-oneClickNL-60e020"},{name:"prop56",dynamic:!1,value:"article-oneClickNL-60e020"}]},{name:"article-mostReadNum",active:!0,"x-persist":!0,"x-status":"1","x-linked":"0",increment:0,segment:{},_token:"c331cb",variations:[{customOptions:{target:"25"},name:"ten",track:[{name:"list1",
# dynamic:!1,value:"article-mostReadNum:ten"},{name:"prop56",dynamic:!1,value:"article-mostReadNum:ten"},{name:"list1",dynamic:!1,value:"article-mostReadNum-c331cb"},{name:"prop56",dynamic:!1,value:"article-mostReadNum-c331cb"}]}],defaultTrack:[{name:"list1",dynamic:!1,value:"article-mostReadNum:default"},{name:"prop56",dynamic:!1,value:"article-mostReadNum:default"},{name:"list1",dynamic:!1,value:"article-mostReadNum-c331cb"},{name:"prop56",dynamic:!1,value:"article-mostReadNum-c331cb"}]},{name:"article-curatedContent",
# active:!1,"x-persist":!0,"x-status":"1","x-linked":"0",increment:1,segment:{},_token:"7d2dac",variations:[{customOptions:{target:"25"},name:"enabledhpfirst",track:[{name:"list1",dynamic:!1,value:"article-curatedContent:enabledhpfirst"},{name:"prop56",dynamic:!1,value:"article-curatedContent:enabledhpfirst"},{name:"list1",dynamic:!1,value:"article-curatedContent-7d2dac"},{name:"prop56",dynamic:!1,value:"article-curatedContent-7d2dac"}]},{customOptions:{target:"25"},name:"enabledprfirst",track:[{name:"list1",
# dynamic:!1,value:"article-curatedContent:enabledprfirst"},{name:"prop56",dynamic:!1,value:"article-curatedContent:enabledprfirst"},{name:"list1",dynamic:!1,value:"article-curatedContent-7d2dac"},{name:"prop56",dynamic:!1,value:"article-curatedContent-7d2dac"}]},{customOptions:{target:"25"},name:"enabledhponly",track:[{name:"list1",dynamic:!1,value:"article-curatedContent:enabledhponly"},{name:"prop56",dynamic:!1,value:"article-curatedContent:enabledhponly"},{name:"list1",dynamic:!1,value:"article-curatedContent-7d2dac"},
# {name:"prop56",dynamic:!1,value:"article-curatedContent-7d2dac"}]}],defaultTrack:[{name:"list1",dynamic:!1,value:"article-curatedContent:default"},{name:"prop56",dynamic:!1,value:"article-curatedContent:default"},{name:"list1",dynamic:!1,value:"article-curatedContent-7d2dac"},{name:"prop56",dynamic:!1,value:"article-curatedContent-7d2dac"}]}]},{name:"modal",disabled:!1,tests:[{name:"modal-adblock_v1",active:!0,"x-persist":!0,"x-status":"1","x-linked":"0",increment:6,segment:{adblock_generic:!0},_token:"61f727",
# variations:[{customOptions:{target:"95"},name:"enabled",track:[{name:"list1",dynamic:!1,value:"modal-adblock_v1:enabled"},{name:"prop56",dynamic:!1,value:"modal-adblock_v1:enabled"},{name:"list1",dynamic:!1,value:"modal-adblock_v1-61f727"},{name:"prop56",dynamic:!1,value:"modal-adblock_v1-61f727"}]}],defaultTrack:[{name:"list1",dynamic:!1,value:"modal-adblock_v1:default"},{name:"prop56",dynamic:!1,value:"modal-adblock_v1:default"},{name:"list1",dynamic:!1,value:"modal-adblock_v1-61f727"},{name:"prop56",
# dynamic:!1,value:"modal-adblock_v1-61f727"}]}]},{name:"video",disabled:!1,tests:[{name:"video-adtimeout",active:!1,"x-persist":!0,"x-status":"1","x-linked":"0",increment:3,segment:{},_token:"397458",variations:[{customOptions:{target:"10"},name:"8s",track:[{name:"list1",dynamic:!1,value:"video-adtimeout:8s"},{name:"prop56",dynamic:!1,value:"video-adtimeout:8s"},{name:"list1",dynamic:!1,value:"video-adtimeout-397458"},{name:"prop56",dynamic:!1,value:"video-adtimeout-397458"}]}],defaultTrack:[{name:"list1",
# dynamic:!1,value:"video-adtimeout:default"},{name:"prop56",dynamic:!1,value:"video-adtimeout:default"},{name:"list1",dynamic:!1,value:"video-adtimeout-397458"},{name:"prop56",dynamic:!1,value:"video-adtimeout-397458"}]}]},{name:"upgrade",disabled:!1,tests:[{name:"upgrade-toolkit_v110",active:!0,"x-persist":!0,"x-status":"1","x-linked":"0",increment:0,segment:{},_token:"fe334d",variations:[{customOptions:{target:"25"},name:"variant_1",track:[{name:"list1",dynamic:!1,value:"upgrade-toolkit_v110:variant_1"},
# {name:"prop56",dynamic:!1,value:"upgrade-toolkit_v110:variant_1"},{name:"list1",dynamic:!1,value:"upgrade-toolkit_v110-fe334d"},{name:"prop56",dynamic:!1,value:"upgrade-toolkit_v110-fe334d"}]}],defaultTrack:[{name:"list1",dynamic:!1,value:"upgrade-toolkit_v110:default"},{name:"prop56",dynamic:!1,value:"upgrade-toolkit_v110:default"},{name:"list1",dynamic:!1,value:"upgrade-toolkit_v110-fe334d"},{name:"prop56",dynamic:!1,value:"upgrade-toolkit_v110-fe334d"}]}]}]});this.__dwCallback__?this.__dwCallback__(m):
# m.init()})(this._dw)}();</script> </div> </div></section> <div class="pb-container"> </div></div> <script>window.pageBuilder&&window.pageBuilder.initVariants&&window.pageBuilder.initVariants({IS_ADMIN:!1,TIMEOUT:wp_pb.banditoEnv.TIMEOUT,PERF_API:wp_pb.banditoEnv.PERF_API,TESTS_API:wp_pb.banditoEnv.TESTS_API,EVENTS_API:wp_pb.banditoEnv.EVENTS_API});</script> <script>console.time("hi-pri-js");</script> <script src="/pb/gr/c/default/r0z7VYYLti3loq/hi-pri-js/e7f066f51e.js?_=3b73d"></script> <script src="/pb/gr/p/default/r0z7VYYLti3loq/hi-pri-render.js?_=c93f7"></script> <script>console.timeEnd("hi-pri-js");</script> <script>window.TWPHead.ready("main.js",function(){window.TWP&&TWP.Analytics&&TWP.Analytics.init({trackScrolling:{omniture:!1},snowflake:!0,suppressTrackPageLoad:wp_pb.StaticMethods.isPageHydrated()?!1:!0})});</script> <noscript><img src="https://sb.scorecardresearch.com/p?c1=2&amp;c2=3005617&amp;cv=2.0&amp;cj=1"/></noscript> <noscript><img alt="" src="//me.effectivemeasure.net/em_image" style="position:absolute; left:-5px;"/></noscript> <script>console.time("js");</script> <script src="/pb/gr/c/default/r0z7VYYLti3loq/js/46707ff31b.js?_=7ecd4"></script> <script>console.timeEnd("js");</script> <script>console.time("render.js");</script> <script src="/pb/gr/p/default/r0z7VYYLti3loq/render.js?_=c93f7"></script> <script>console.timeEnd("render.js");</script> <script>console.time("instance.js");</script> <script src="/pb/gr/p/default/r0z7VYYLti3loq/instance.js?_=c93f7"></script> <script>console.timeEnd("instance.js");</script> <script>console.time("after_features");</script> <script src="/pb/gr/c/default/r0z7VYYLti3loq/after_features/82e93e7bf2.js?_=96a67"></script> <script>console.timeEnd("after_features");</script> <script>console.time("content_type_article");</script> <script>console.timeEnd("content_type_article");</script> <script>console.time("third_party");</script> <script>console.timeEnd("third_party");</script> <script>(function(){"__twpCookieMonster__"in document&&document.__twpCookieMonster__.ommNom()})();</script> <script>jQuery(function(){function a(){try{var a=$(".tweet-authors");!a.length||window.twttr&&twttr.widgets||$.ajax({dataType:"script",cache:!0,url:"//platform.twitter.com/widgets.js",success:function(b){a.find(".pb-twitter-follow.unprocessed").removeClass("unprocessed")}});$.ajax({dataType:"script",cache:!0,url:"//ak.sail-horizon.com/horizon/v1.js",success:function(a){window.Sailthru&&Sailthru.setup({domain:"horizon.washingtonpost.com"})}})}catch(c){}}wp_pb.StaticMethods.isPageHydrated()&&a();__e.push(["shamble:end",
# function(){a()}])});</script> <script>jQuery(function(){try{$("body").append('\x3cimg src\x3d"https://amplifypixel.outbrain.com/pixel?mid\x3d00bb70a80ee8f020d9011cbcef307fe64d"\x3e')}catch(a){}});</script> <script>!function(){if(!(99<Math.floor(100*Math.random()))){var c,b,d,a=document.createElement("iframe");a.src="javascript:false";(a.frameElement||a).style.cssText="width: 0; height: 0; border: 0";d=document.getElementsByTagName("script")[0];d.parentNode.insertBefore(a,d);try{b=a.contentWindow.document}catch(e){c=document.domain,a.src="javascript:var d\x3ddocument.open();d.domain\x3d'"+c+"';void(0);",b=a.contentWindow.document}b.open()._l=function(){var a=this.createElement("script");c&&(this.domain=c);a.id=
# "boomr-if-as";a.src="//www.washingtonpost.com/wp-stat/rum/wprum.min.js";this.body.appendChild(a)};b.write('\x3cbody onload\x3d"document._l();"\x3e');b.close()}}();</script> <script>ResourceBundle.processInlineScripts();</script> </body> </html>

# %% [markdown]
# #### Retrieve and combine all texts from the article element

# %%
text = ' '.join(map(lambda p: p.text, soup.find_all('article')))

# %% [markdown]
# #### Review our text

# %%
text
# Out:
# ' Republican female senators whose disapproval of the GOP health-care effort has at times endangered its progress are facing an increasingly pointed backlash from men in their party, including a handful of comments that invoked physical retaliation. In the past week, Sen. Susan Collins (Maine) has been challenged by a male lawmaker to a duel. She and Sen. Lisa Murkowski (Alaska) were told that they and others deserve a physical reprimand for their decisions not to support Republican health-care proposals. Murkowski, who voted with Collins against starting the health-care debate this week, was specifically called out by President Trump on Twitter and told by a Cabinet official that Alaska could suffer for her choice, according to a colleague.  The language of retribution increasingly adopted by Republican men reflects Trump’s influence and underscores the challenges GOP women can face when opposing the consensus of their party, which remains dominated by men, outside experts said. A videotape of Trump surfaced during the campaign revealing him bragging in vulgar terms about groping women, and some believed that opened the gates for further insults and degrading behavior toward women. “Masculine dominance in the Republican Party is not only in numbers but in culture,” said Kelly Dittmar, a scholar at the Center for American Women and Politics at Rutgers University and the author of “Navigating Gendered Terrain: Stereotypes and Strategy in Political Campaigns.”   “When the person who is supposed to be the leader of the party shows it’s okay to use those sorts of attacks, whether they are specifically gendered or not, that is something that catches on at other levels,” Dittmar said. “We see it in the [elected officials] who feel it’s okay to say things like this.”       (Amber Ferguson/The Washington Post)    [Senate GOP leaders work to round up votes for modest health-care overhaul]  Collins and Murkowski have been among the Senate’s most consistently skeptical voices as Republicans accelerate their effort to amend the 2010 Affordable Care Act (ACA). In contrast with conservative critics such as Sen. Rand Paul (R-Ky.), both women have criticized GOP health-care proposals because they would cut funding to Medicaid and Planned Parenthood, which provide medical care to hundreds of thousands of people in their states. Both have raised concerns about a lack of transparency in the crafting of GOP legislation. They are not the only critics who have faced political attack over health-care legislation, but the backlash has not been as aggressive. Notably, the pro-Trump political outfit America First Policies targeted Sen. Dean Heller (Nev.) with $1\xa0million in TV and radio ads last month after he announced opposition to one ACA overhaul bill. The group canceled its campaign after senior Republicans intervened on Heller’s behalf.  [See the anti-Heller ad here]  Trump also has threatened electoral consequences against Republican senators who oppose the party consensus on health care. “Look, he wants to remain a senator, doesn’t he?” the president said recently of Heller, who was seated next to him at a lunch event. “I think the people of your state .\u2009.\u2009. [are] going to appreciate what you hopefully will do.” Still, the most colorful and threatening comments have targeted Collins and Murkowski.  Rep. Blake Farenthold (Tex.), in an apparent reference to Collins, told a radio host Friday that if she were a “guy from south Texas, I might ask him to step outside and settle this Aaron Burr-style,” invoking the 1804 duel in which Alexander Hamilton was killed.  “Like the President, I am sick and tired of the left-wing biased media trying to make something out of nothing,” he said in a follow-up statement. “This was clearly tongue in cheek. That being said, I’m extremely frustrated with Senate Republicans who are breaking their promise to the American people to repeal and replace Obamacare.” Collins was caught on a hot mic responding, w ...

# %% [markdown]
# #### Module to retrieve text

# %%
def getTextWapo(url):
   page = urllib.request.urlopen(url).read().decode('utf8','ignore')
   soup = BeautifulSoup(page,"lxml") 
   text = ' '.join(map(lambda p: p.text, soup.find_all('article')))
   return text

# %% [markdown]
# #### Module to retrieve image

# %%
def getImages(url):
    r = urllib.request.urlopen(url).read()
    soup = BeautifulSoup(r,"lxml")  # Setup a "soup" which BeautifulSoup can search
    links = []
    for link in soup.find_all('img'):  # Cycle through all 'img' tags
        imgSrc = link.get('src')  # Extract the 'src' from those tags
        links.append(imgSrc)  # Append the source to 'links'
    return links  # Return 'links'

# %% [markdown]
# #### check that we have image from article

# %%
images = getImages("https://www.washingtonpost.com/news/post-politics/wp/2017/07/27/scaramucci-if-reince-wants-to-explain-that-hes-not-a-leaker-let-him-do-that/?tid=pm_pop_b&utm_term=.9491b116a4eb")

# %% [markdown]
# #### Retrieve image link from the array

# %%
images[8]
# Out:
# 'https://www.washingtonpost.com/graphics/politics/can-he-do-that-trump-podcast/images/8_CanHeDoThat_LSR_small.jpg'

# %% [markdown]
# ### Preprocess Text using the NLTK Library

# %%
# Used to break down text into sentences and words
from nltk.tokenize import sent_tokenize,word_tokenize

#Used to create a list of stop words from the article
from nltk.corpus import stopwords
from string import punctuation

# %% [markdown]
# #### Tokenize the text into sentences

# %%
sents = sent_tokenize(text)

# %% [markdown]
# #### Review that text has been tokenized into sentences

# %%
sents
# Out:
# [' Republican female senators whose disapproval of the GOP health-care effort has at times endangered its progress are facing an increasingly pointed backlash from men in their party, including a handful of comments that invoked physical retaliation.',
#  'In the past week, Sen. Susan Collins (Maine) has been challenged by a male lawmaker to a duel.',
#  'She and Sen. Lisa Murkowski (Alaska) were told that they and others deserve a physical reprimand for their decisions not to support Republican health-care proposals.',
#  'Murkowski, who voted with Collins against starting the health-care debate this week, was specifically called out by President Trump on Twitter and told by a Cabinet official that Alaska could suffer for her choice, according to a colleague.',
#  'The language of retribution increasingly adopted by Republican men reflects Trump’s influence and underscores the challenges GOP women can face when opposing the consensus of their party, which remains dominated by men, outside experts said.',
#  'A videotape of Trump surfaced during the campaign revealing him bragging in vulgar terms about groping women, and some believed that opened the gates for further insults and degrading behavior toward women.',
#  '“Masculine dominance in the Republican Party is not only in numbers but in culture,” said Kelly Dittmar, a scholar at the Center for American Women and Politics at Rutgers University and the author of “Navigating Gendered Terrain: Stereotypes and Strategy in Political Campaigns.”   “When the person who is supposed to be the leader of the party shows it’s okay to use those sorts of attacks, whether they are specifically gendered or not, that is something that catches on at other levels,” Dittmar said.',
#  '“We see it in the [elected officials] who feel it’s okay to say things like this.”       (Amber Ferguson/The Washington Post)    [Senate GOP leaders work to round up votes for modest health-care overhaul]  Collins and Murkowski have been among the Senate’s most consistently skeptical voices as Republicans accelerate their effort to amend the 2010 Affordable Care Act (ACA).',
#  'In contrast with conservative critics such as Sen. Rand Paul (R-Ky.), both women have criticized GOP health-care proposals because they would cut funding to Medicaid and Planned Parenthood, which provide medical care to hundreds of thousands of people in their states.',
#  'Both have raised concerns about a lack of transparency in the crafting of GOP legislation.',
#  'They are not the only critics who have faced political attack over health-care legislation, but the backlash has not been as aggressive.',
#  'Notably, the pro-Trump political outfit America First Policies targeted Sen. Dean Heller (Nev.) with $1\xa0million in TV and radio ads last month after he announced opposition to one ACA overhaul bill.',
#  'The group canceled its campaign after senior Republicans intervened on Heller’s behalf.',
#  '[See the anti-Heller ad here]  Trump also has threatened electoral consequences against Republican senators who oppose the party consensus on health care.',
#  '“Look, he wants to remain a senator, doesn’t he?” the president said recently of Heller, who was seated next to him at a lunch event.',
#  '“I think the people of your state .',
#  '.',
#  '.',
#  '[are] going to appreciate what you hopefully will do.” Still, the most colorful and threatening comments have targeted Collins and Murkowski.',
#  'Rep. Blake Farenthold (Tex.',
#  '), in an apparent reference to Collins, told a radio host Friday that if she were a “guy from south Texas, I might ask him to step outside and settle this Aaron Burr-style,” invoking the 1804 duel in which Alexander Hamilton was killed.',
#  '“Like the President, I am sick and tired of the left-wing biased media trying to make something out of nothing,” he said in a follow-up statement.',
#  '“This was clearly tongue in cheek.',
#  'That being said, I’m extremely frustrated with Senate Republicans who are breaking their promise to the American people to repeal and replace Obamacare.” Collins was caught on a hot mic responding, when Sen. Jack Reed (D-R.I.) said she could beat Farenthold in such a duel.',
#  'Collins called Fahrenthold “huge” and “extremely unattractive.” They later apologized to each other, CNN reported.',
#  'Rep. Earl L. “Buddy” Carter (R-Ga.) told MSNBC on Wednesday that someone should “go over there to that Senate and snatch a knot in their a--,” a regional phrase that refers to punishment, usually of disobedient children.',
#  'MSNBC reporter Ali Velshi had asked Carter what he thought of Trump’s tweet chastising Murkowski for opposing the start of the health-care debate.',
#  'Carter later said the remark was directed at all those senators who, like Murkowski, stood in the way of easy victory for the legislation.',
#  '“Rep.',
#  'Carter’s comment was in no way directed toward Senator Murkowski specifically,” Carter spokeswoman Mary Carpenter wrote in an email.',
#  '“His words speak for themselves that he was not speaking about a single senator.',
#  'This is a southern phrase used frequently throughout Rep. Carter’s lifetime which simply means get your act together.”  The comments are particularly poignant, given that Republican women in the Senate were excluded from the chamber’s original working group on health care.',
#  '“It’s too bad some folks are spending so much time creating cute catchy phrases in order to take potshots at colleagues,” Julie A. Conway, executive director of VIEW PAC, which recruits and trains Republican female candidates, wrote in an email.',
#  '“I wish they would spend as much time and energy sitting down with these women lawmakers to help find solutions and a strategy to get real health-care reform that Americans can feel good about.” Dittmar argued that these kinds of comments undermine female leaders in the long run.',
#  '“The fact they call out specific women marks those women as outside of the norm.',
#  'For those who may question women’s capacity to be just as qualified as elected officials, it mines that vein of doubt or underlying bias,” she said.',
#  'Trump’s rhetoric has been almost calm by comparison.',
#  '“Senator @lisamurkowski of the Great State of Alaska really let the Republicans, and our country, down yesterday.',
#  'Too bad!” he tweeted Wednesday morning.',
#  'But later in the day, according to the Alaska Dispatch News, Interior Secretary Ryan Zinke called Murkowski and Sen. Dan Sullivan (R-Alaska) to say that Murkowski’s vote against opening the health-care debate could have repercussions for federal policy affecting Alaska.',
#  '“The message was pretty clear,” Sullivan told the news outlet.',
#  'The next day, a nominations markup in the Senate Energy and Natural Resources Committee was postponed, leading some observers to speculate that Murkowski — the panel’s chairman — had deferred it in retaliation for Zinke’s call.',
#  'A spokeswoman for the committee told The Washington Post that the meeting was postponed because of the uncertainty of the Senate schedule.',
#  'Mike DeBonis contributed to this report.',
#  'Read more at PowerPost']

# %% [markdown]
# #### Tokenize the text into words

# %%
word_sent = word_tokenize(text.lower())

# %% [markdown]
# #### Review that the text has been tokenized into words

# %%
word_sent
# Out:
# ['republican',
#  'female',
#  'senators',
#  'whose',
#  'disapproval',
#  'of',
#  'the',
#  'gop',
#  'health-care',
#  'effort',
#  'has',
#  'at',
#  'times',
#  'endangered',
#  'its',
#  'progress',
#  'are',
#  'facing',
#  'an',
#  'increasingly',
#  'pointed',
#  'backlash',
#  'from',
#  'men',
#  'in',
#  'their',
#  'party',
#  ',',
#  'including',
#  'a',
#  'handful',
#  'of',
#  'comments',
#  'that',
#  'invoked',
#  'physical',
#  'retaliation',
#  '.',
#  'in',
#  'the',
#  'past',
#  'week',
#  ',',
#  'sen.',
#  'susan',
#  'collins',
#  '(',
#  'maine',
#  ')',
#  'has',
#  'been',
#  'challenged',
#  'by',
#  'a',
#  'male',
#  'lawmaker',
#  'to',
#  'a',
#  'duel',
#  '.',
#  'she',
#  'and',
#  'sen.',
#  'lisa',
#  'murkowski',
#  '(',
#  'alaska',
#  ')',
#  'were',
#  'told',
#  'that',
#  'they',
#  'and',
#  'others',
#  'deserve',
#  'a',
#  'physical',
#  'reprimand',
#  'for',
#  'their',
#  'decisions',
#  'not',
#  'to',
#  'support',
#  'republican',
#  'health-care',
#  'proposals',
#  '.',
#  'murkowski',
#  ',',
#  'who',
#  'voted',
#  'with',
#  'collins',
#  'against',
#  'starting',
#  'the',
#  'health-care',
#  'debate',
#  'this',
#  'week',
#  ',',
#  'was',
#  'specifically',
#  'called',
#  'out',
#  'by',
#  'president',
#  'trump',
#  'on',
#  'twitter',
#  'and',
#  'told',
#  'by',
#  'a',
#  'cabinet',
#  'official',
#  'that',
#  'alaska',
#  'could',
#  'suffer',
#  'for',
#  'her',
#  'choice',
#  ',',
#  'according',
#  'to',
#  'a',
#  'colleague',
#  '.',
#  'the',
#  'language',
#  'of',
#  'retribution',
#  'increasingly',
#  'adopted',
#  'by',
#  'republican',
#  'men',
#  'reflects',
#  'trump',
#  '’',
#  's',
#  'influence',
#  'and',
#  'underscores',
#  'the',
#  'challenges',
#  'gop',
#  'women',
#  'can',
#  'face',
#  'when',
#  'opposing',
#  'the',
#  'consensus',
#  'of',
#  'their',
#  'party',
#  ',',
#  'which',
#  'remains',
#  'dominated',
#  'by',
#  'men',
#  ',',
#  'outside',
#  'experts',
#  'said',
#  '.',
#  'a',
#  'videotape',
#  'of',
#  'trump',
#  'surfaced',
#  'during',
#  'the',
#  'campaign',
#  'revealing',
#  'him',
#  'bragging',
#  'in',
#  'vulgar',
#  'terms',
#  'about',
#  'groping',
#  'women',
#  ',',
#  'and',
#  'some',
#  'believed',
#  'that',
#  'opened',
#  'the',
#  'gates',
#  'for',
#  'further',
#  'insults',
#  'and',
#  'degrading',
#  'behavior',
#  'toward',
#  'women',
#  '.',
#  '“',
#  'masculine',
#  'dominance',
#  'in',
#  'the',
#  'republican',
#  'party',
#  'is',
#  'not',
#  'only',
#  'in',
#  'numbers',
#  'but',
#  'in',
#  'culture',
#  ',',
#  '”',
#  'said',
#  'kelly',
#  'dittmar',
#  ',',
#  'a',
#  'scholar',
#  'at',
#  'the',
#  'center',
#  'for',
#  'american',
#  'women',
#  'and',
#  'politics',
#  'at',
#  'rutgers',
#  'university',
#  'and',
#  'the',
#  'author',
#  'of',
#  '“',
#  'navigating',
#  'gendered',
#  'terrain',
#  ':',
#  'stereotypes',
#  'and',
#  'strategy',
#  'in',
#  'political',
#  'campaigns.',
#  '”',
#  '“',
#  'when',
#  'the',
#  'person',
#  'who',
#  'is',
#  'supposed',
#  'to',
#  'be',
#  'the',
#  'leader',
#  'of',
#  'the',
#  'party',
#  'shows',
#  'it',
#  '’',
#  's',
#  'okay',
#  'to',
#  'use',
#  'those',
#  'sorts',
#  'of',
#  'attacks',
#  ',',
#  'whether',
#  'they',
#  'are',
#  'specifically',
#  'gendered',
#  'or',
#  'not',
#  ',',
#  'that',
#  'is',
#  'something',
#  'that',
#  'catches',
#  'on',
#  'at',
#  'other',
#  'levels',
#  ',',
#  '”',
#  'dittmar',
#  'said',
#  '.',
#  '“',
#  'we',
#  'see',
#  'it',
#  'in',
#  'the',
#  '[',
#  'elected',
#  'officials',
#  ']',
#  'who',
#  'feel',
#  'it',
#  '’',
#  's',
#  'okay',
#  'to',
#  'say',
#  'things',
#  'like',
#  'this.',
#  '”',
#  '(',
#  'amber',
#  'ferguson/the',
#  'washington',
#  'post',
#  ')',
#  '[',
#  'senate',
#  'gop',
#  'leaders',
#  'work',
#  'to',
#  'round',
#  'up',
#  'votes',
#  'for',
#  'modest',
#  'health-care',
#  'overhaul',
#  ']',
#  'collins',
#  'and',
#  'murkowski',
#  'have',
#  'been',
#  'among',
#  'the',
#  'senate',
#  '’',
#  's',
#  'most',
#  'consistently',
#  'skeptical',
#  'voices',
#  'as',
#  'republicans',
#  'accelerate',
#  'their',
#  'effort',
#  'to',
#  'amend',
#  'the',
#  '2010',
#  'affordable',
#  'care',
#  'act',
#  '(',
#  'aca',
#  ')',
#  '.',
#  'in',
#  'contrast',
#  'with',
#  'conservative',
#  'critics',
#  'such',
#  'as',
#  'sen.',
#  'rand',
#  'paul',
#  '(',
#  'r-ky.',
#  ')',
#  ',',
#  'both',
#  'women',
#  'have',
#  'criticized',
#  'gop',
#  'health-care',
#  'proposals',
#  'because',
#  'they',
#  'would',
#  'cut',
#  'funding',
#  'to',
#  'medicaid',
#  'and',
#  'planned',
#  'parenthood',
#  ',',
#  'which',
#  'provide',
#  'medical',
#  'care',
#  'to',
#  'hundreds',
#  'of',
#  'thousands',
#  'of',
#  'people',
#  'in',
#  'their',
#  'states',
#  '.',
#  'both',
#  'have',
#  'raised',
#  'concerns',
#  'about',
#  'a',
#  'lack',
#  'of',
#  'transparency',
#  'in',
#  'the',
#  'crafting',
#  'of',
#  'gop',
#  'legislation',
#  '.',
#  'they',
#  'are',
#  'not',
#  'the',
#  'only',
#  'critics',
#  'who',
#  'have',
#  'faced',
#  'political',
#  'attack',
#  'over',
#  'health-care',
#  'legislation',
#  ',',
#  'but',
#  'the',
#  'backlash',
#  'has',
#  'not',
#  'been',
#  'as',
#  'aggressive',
#  '.',
#  'notably',
#  ',',
#  'the',
#  'pro-trump',
#  'political',
#  'outfit',
#  'america',
#  'first',
#  'policies',
#  'targeted',
#  'sen.',
#  'dean',
#  'heller',
#  '(',
#  'nev.',
#  ')',
#  'with',
#  '$',
#  '1',
#  'million',
#  'in',
#  'tv',
#  'and',
#  'radio',
#  'ads',
#  'last',
#  'month',
#  'after',
#  'he',
#  'announced',
#  'opposition',
#  'to',
#  'one',
#  'aca',
#  'overhaul',
#  'bill',
#  '.',
#  'the',
#  'group',
#  'canceled',
#  'its',
#  'campaign',
#  'after',
#  'senior',
#  'republicans',
#  'intervened',
#  'on',
#  'heller',
#  '’',
#  's',
#  'behalf',
#  '.',
#  '[',
#  'see',
#  'the',
#  'anti-heller',
#  'ad',
#  'here',
#  ']',
#  'trump',
#  'also',
#  'has',
#  'threatened',
#  'electoral',
#  'consequences',
#  'against',
#  'republican',
#  'senators',
#  'who',
#  'oppose',
#  'the',
#  'party',
#  'consensus',
#  'on',
#  'health',
#  'care',
#  '.',
#  '“',
#  'look',
#  ',',
#  'he',
#  'wants',
#  'to',
#  'remain',
#  'a',
#  'senator',
#  ',',
#  'doesn',
#  '’',
#  't',
#  'he',
#  '?',
#  '”',
#  'the',
#  'president',
#  'said',
#  'recently',
#  'of',
#  'heller',
#  ',',
#  'who',
#  'was',
#  'seated',
#  'next',
#  'to',
#  'him',
#  'at',
#  'a',
#  'lunch',
#  'event',
#  '.',
#  '“',
#  'i',
#  'think',
#  'the',
#  'people',
#  'of',
#  'your',
#  'state',
#  '.',
#  '.',
#  '.',
#  '[',
#  'are',
#  ']',
#  'going',
#  'to',
#  'appreciate',
#  'what',
#  'you',
#  'hopefully',
#  'will',
#  'do.',
#  '”',
#  'still',
#  ',',
#  'the',
#  'most',
#  'colorful',
#  'and',
#  'threatening',
#  'comments',
#  'have',
#  'targeted',
#  'collins',
#  'and',
#  'murkowski',
#  '.',
#  'rep.',
#  'blake',
#  'farenthold',
#  '(',
#  'tex',
#  '.',
#  ')',
#  ',',
#  'in',
#  'an',
#  'apparent',
#  'reference',
#  'to',
#  'collins',
#  ',',
#  'told',
#  'a',
#  'radio',
#  'host',
#  'friday',
#  'that',
#  'if',
#  'she',
#  'were',
#  'a',
#  '“',
#  'guy',
#  'from',
#  'south',
#  'texas',
#  ',',
#  'i',
#  'might',
#  'ask',
#  'him',
#  'to',
#  'step',
#  'outside',
#  'and',
#  'settle',
#  'this',
#  'aaron',
#  'burr-style',
#  ',',
#  '”',
#  'invoking',
#  'the',
#  '1804',
#  'duel',
#  'in',
#  'which',
#  'alexander',
#  'hamilton',
#  'was',
#  'killed',
#  '.',
#  '“',
#  'like',
#  'the',
#  'president',
#  ',',
#  'i',
#  'am',
#  'sick',
#  'and',
#  'tired',
#  'of',
#  'the',
#  'left-wing',
#  'biased',
#  'media',
#  'trying',
#  'to',
#  'make',
#  'something',
#  'out',
#  'of',
#  'nothing',
#  ',',
#  '”',
#  'he',
#  'said',
#  'in',
#  'a',
#  'follow-up',
#  'statement',
#  '.',
#  '“',
#  'this',
#  'was',
#  'clearly',
#  'tongue',
#  'in',
#  'cheek',
#  '.',
#  'that',
#  'being',
#  'said',
#  ',',
#  'i',
#  '’',
#  'm',
#  'extremely',
#  'frustrated',
#  'with',
#  'senate',
#  'republicans',
#  'who',
#  'are',
#  'breaking',
#  'their',
#  'promise',
#  'to',
#  'the',
#  'american',
#  'people',
#  'to',
#  'repeal',
#  'and',
#  'replace',
#  'obamacare.',
#  '”',
#  'collins',
#  'was',
#  'caught',
#  'on',
#  'a',
#  'hot',
#  'mic',
#  'responding',
#  ',',
#  'when',
#  'sen.',
#  'jack',
#  'reed',
#  '(',
#  'd-r.i.',
#  ')',
#  'said',
#  'she',
#  'could',
#  'beat',
#  'farenthold',
#  'in',
#  'such',
#  'a',
#  'duel',
#  '.',
#  'collins',
#  'called',
#  'fahrenthold',
#  '“',
#  'huge',
#  '”',
#  'and',
#  '“',
#  'extremely',
#  'unattractive.',
#  '”',
#  'they',
#  'later',
#  'apologized',
#  'to',
#  'each',
#  'other',
#  ',',
#  'cnn',
#  'reported',
#  '.',
#  'rep.',
#  'earl',
#  'l.',
#  '“',
#  'buddy',
#  '”',
#  'carter',
#  '(',
#  'r-ga.',
#  ')',
#  'told',
#  'msnbc',
#  'on',
#  'wednesday',
#  'that',
#  'someone',
#  'should',
#  '“',
#  'go',
#  'over',
#  'there',
#  'to',
#  'that',
#  'senate',
#  'and',
#  'snatch',
#  'a',
#  'knot',
#  'in',
#  'their',
#  'a',
#  '--',
#  ',',
#  '”',
#  'a',
#  'regional',
#  'phrase',
#  'that',
#  'refers',
#  'to',
#  'punishment',
#  ',',
#  'usually',
#  'of',
#  'disobedient',
#  'children',
#  '.',
#  'msnbc',
#  'reporter',
#  'ali',
#  'velshi',
#  'had',
#  'asked',
#  'carter',
#  'what',
#  'he',
#  'thought',
#  'of',
#  'trump',
#  '’',
#  's',
#  'tweet',
#  'chastising',
#  'murkowski',
#  'for',
#  'opposing',
#  'the',
#  'start',
#  'of',
#  'the',
#  'health-care',
#  'debate',
#  '.',
#  'carter',
#  'later',
#  'said',
#  'the',
#  'remark',
#  'was',
#  'directed',
#  'at',
#  'all',
#  'those',
#  'senators',
#  'who',
#  ',',
#  'like',
#  'murkowski',
#  ',',
#  'stood',
#  'in',
#  'the',
#  'way',
#  'of',
#  'easy',
#  'victory',
#  'for',
#  'the',
#  'legislation',
#  '.',
#  '“',
#  'rep',
#  '.',
#  'carter',
#  '’',
#  's',
#  'comment',
#  'was',
#  'in',
#  'no',
#  'way',
#  'directed',
#  'toward',
#  'senator',
#  'murkowski',
#  'specifically',
#  ',',
#  '”',
#  'carter',
#  'spokeswoman',
#  'mary',
#  'carpenter',
#  'wrote',
#  'in',
#  'an',
#  'email',
#  '.',
#  '“',
#  'his',
#  'words',
#  'speak',
#  'for',
#  'themselves',
#  'that',
#  'he',
#  'was',
#  'not',
#  'speaking',
#  'about',
#  'a',
#  'single',
#  'senator',
#  '.',
#  'this',
#  'is',
#  'a',
#  'southern',
#  'phrase',
#  'used',
#  'frequently',
#  'throughout',
#  'rep.',
#  'carter',
#  '’',
#  's',
#  'lifetime',
#  'which',
#  'simply',
#  'means',
#  'get',
#  'your',
#  'act',
#  'together.',
#  '”',
#  'the',
#  'comments',
#  'are',
#  'particularly',
#  'poignant',
#  ',',
#  'given',
#  'that',
#  'republican',
#  'women',
#  'in',
#  'the',
#  'senate',
#  'were',
#  'excluded',
#  'from',
#  'the',
#  'chamber',
#  '’',
#  's',
#  'original',
#  'working',
#  'group',
#  'on',
#  'health',
#  'care',
#  '.',
#  '“',
#  'it',
#  '’',
#  's',
#  'too',
#  'bad',
#  'some',
#  'folks',
#  'are',
#  'spending',
#  'so',
#  'much',
#  'time',
#  'creating',
#  'cute',
#  'catchy',
#  'phrases',
#  'in',
#  'order',
#  'to',
#  'take',
#  'potshots',
#  'at',
#  'colleagues',
#  ',',
#  '”',
#  'julie',
#  'a.',
#  'conway',
#  ',',
#  'executive',
#  'director',
#  ...]

# %% [markdown]
# #### Remove Stop words

# %%
_stopwords = set(stopwords.words('english') + list(punctuation))

# %%
word_sent=[word for word in word_sent if word not in _stopwords]

# %% [markdown]
# #### Review that we have removed stop words from our list of words

# %%
word_sent
# Out:
# ['republican',
#  'female',
#  'senators',
#  'whose',
#  'disapproval',
#  'of',
#  'the',
#  'gop',
#  'health-care',
#  'effort',
#  'has',
#  'at',
#  'times',
#  'endangered',
#  'its',
#  'progress',
#  'are',
#  'facing',
#  'an',
#  'increasingly',
#  'pointed',
#  'backlash',
#  'from',
#  'men',
#  'in',
#  'their',
#  'party',
#  ',',
#  'including',
#  'a',
#  'handful',
#  'of',
#  'comments',
#  'that',
#  'invoked',
#  'physical',
#  'retaliation',
#  '.',
#  'in',
#  'the',
#  'past',
#  'week',
#  ',',
#  'sen.',
#  'susan',
#  'collins',
#  '(',
#  'maine',
#  ')',
#  'has',
#  'been',
#  'challenged',
#  'by',
#  'a',
#  'male',
#  'lawmaker',
#  'to',
#  'a',
#  'duel',
#  '.',
#  'she',
#  'and',
#  'sen.',
#  'lisa',
#  'murkowski',
#  '(',
#  'alaska',
#  ')',
#  'were',
#  'told',
#  'that',
#  'they',
#  'and',
#  'others',
#  'deserve',
#  'a',
#  'physical',
#  'reprimand',
#  'for',
#  'their',
#  'decisions',
#  'not',
#  'to',
#  'support',
#  'republican',
#  'health-care',
#  'proposals',
#  '.',
#  'murkowski',
#  ',',
#  'who',
#  'voted',
#  'with',
#  'collins',
#  'against',
#  'starting',
#  'the',
#  'health-care',
#  'debate',
#  'this',
#  'week',
#  ',',
#  'was',
#  'specifically',
#  'called',
#  'out',
#  'by',
#  'president',
#  'trump',
#  'on',
#  'twitter',
#  'and',
#  'told',
#  'by',
#  'a',
#  'cabinet',
#  'official',
#  'that',
#  'alaska',
#  'could',
#  'suffer',
#  'for',
#  'her',
#  'choice',
#  ',',
#  'according',
#  'to',
#  'a',
#  'colleague',
#  '.',
#  'the',
#  'language',
#  'of',
#  'retribution',
#  'increasingly',
#  'adopted',
#  'by',
#  'republican',
#  'men',
#  'reflects',
#  'trump',
#  '’',
#  's',
#  'influence',
#  'and',
#  'underscores',
#  'the',
#  'challenges',
#  'gop',
#  'women',
#  'can',
#  'face',
#  'when',
#  'opposing',
#  'the',
#  'consensus',
#  'of',
#  'their',
#  'party',
#  ',',
#  'which',
#  'remains',
#  'dominated',
#  'by',
#  'men',
#  ',',
#  'outside',
#  'experts',
#  'said',
#  '.',
#  'a',
#  'videotape',
#  'of',
#  'trump',
#  'surfaced',
#  'during',
#  'the',
#  'campaign',
#  'revealing',
#  'him',
#  'bragging',
#  'in',
#  'vulgar',
#  'terms',
#  'about',
#  'groping',
#  'women',
#  ',',
#  'and',
#  'some',
#  'believed',
#  'that',
#  'opened',
#  'the',
#  'gates',
#  'for',
#  'further',
#  'insults',
#  'and',
#  'degrading',
#  'behavior',
#  'toward',
#  'women',
#  '.',
#  '“',
#  'masculine',
#  'dominance',
#  'in',
#  'the',
#  'republican',
#  'party',
#  'is',
#  'not',
#  'only',
#  'in',
#  'numbers',
#  'but',
#  'in',
#  'culture',
#  ',',
#  '”',
#  'said',
#  'kelly',
#  'dittmar',
#  ',',
#  'a',
#  'scholar',
#  'at',
#  'the',
#  'center',
#  'for',
#  'american',
#  'women',
#  'and',
#  'politics',
#  'at',
#  'rutgers',
#  'university',
#  'and',
#  'the',
#  'author',
#  'of',
#  '“',
#  'navigating',
#  'gendered',
#  'terrain',
#  ':',
#  'stereotypes',
#  'and',
#  'strategy',
#  'in',
#  'political',
#  'campaigns.',
#  '”',
#  '“',
#  'when',
#  'the',
#  'person',
#  'who',
#  'is',
#  'supposed',
#  'to',
#  'be',
#  'the',
#  'leader',
#  'of',
#  'the',
#  'party',
#  'shows',
#  'it',
#  '’',
#  's',
#  'okay',
#  'to',
#  'use',
#  'those',
#  'sorts',
#  'of',
#  'attacks',
#  ',',
#  'whether',
#  'they',
#  'are',
#  'specifically',
#  'gendered',
#  'or',
#  'not',
#  ',',
#  'that',
#  'is',
#  'something',
#  'that',
#  'catches',
#  'on',
#  'at',
#  'other',
#  'levels',
#  ',',
#  '”',
#  'dittmar',
#  'said',
#  '.',
#  '“',
#  'we',
#  'see',
#  'it',
#  'in',
#  'the',
#  '[',
#  'elected',
#  'officials',
#  ']',
#  'who',
#  'feel',
#  'it',
#  '’',
#  's',
#  'okay',
#  'to',
#  'say',
#  'things',
#  'like',
#  'this.',
#  '”',
#  '(',
#  'amber',
#  'ferguson/the',
#  'washington',
#  'post',
#  ')',
#  '[',
#  'senate',
#  'gop',
#  'leaders',
#  'work',
#  'to',
#  'round',
#  'up',
#  'votes',
#  'for',
#  'modest',
#  'health-care',
#  'overhaul',
#  ']',
#  'collins',
#  'and',
#  'murkowski',
#  'have',
#  'been',
#  'among',
#  'the',
#  'senate',
#  '’',
#  's',
#  'most',
#  'consistently',
#  'skeptical',
#  'voices',
#  'as',
#  'republicans',
#  'accelerate',
#  'their',
#  'effort',
#  'to',
#  'amend',
#  'the',
#  '2010',
#  'affordable',
#  'care',
#  'act',
#  '(',
#  'aca',
#  ')',
#  '.',
#  'in',
#  'contrast',
#  'with',
#  'conservative',
#  'critics',
#  'such',
#  'as',
#  'sen.',
#  'rand',
#  'paul',
#  '(',
#  'r-ky.',
#  ')',
#  ',',
#  'both',
#  'women',
#  'have',
#  'criticized',
#  'gop',
#  'health-care',
#  'proposals',
#  'because',
#  'they',
#  'would',
#  'cut',
#  'funding',
#  'to',
#  'medicaid',
#  'and',
#  'planned',
#  'parenthood',
#  ',',
#  'which',
#  'provide',
#  'medical',
#  'care',
#  'to',
#  'hundreds',
#  'of',
#  'thousands',
#  'of',
#  'people',
#  'in',
#  'their',
#  'states',
#  '.',
#  'both',
#  'have',
#  'raised',
#  'concerns',
#  'about',
#  'a',
#  'lack',
#  'of',
#  'transparency',
#  'in',
#  'the',
#  'crafting',
#  'of',
#  'gop',
#  'legislation',
#  '.',
#  'they',
#  'are',
#  'not',
#  'the',
#  'only',
#  'critics',
#  'who',
#  'have',
#  'faced',
#  'political',
#  'attack',
#  'over',
#  'health-care',
#  'legislation',
#  ',',
#  'but',
#  'the',
#  'backlash',
#  'has',
#  'not',
#  'been',
#  'as',
#  'aggressive',
#  '.',
#  'notably',
#  ',',
#  'the',
#  'pro-trump',
#  'political',
#  'outfit',
#  'america',
#  'first',
#  'policies',
#  'targeted',
#  'sen.',
#  'dean',
#  'heller',
#  '(',
#  'nev.',
#  ')',
#  'with',
#  '$',
#  '1',
#  'million',
#  'in',
#  'tv',
#  'and',
#  'radio',
#  'ads',
#  'last',
#  'month',
#  'after',
#  'he',
#  'announced',
#  'opposition',
#  'to',
#  'one',
#  'aca',
#  'overhaul',
#  'bill',
#  '.',
#  'the',
#  'group',
#  'canceled',
#  'its',
#  'campaign',
#  'after',
#  'senior',
#  'republicans',
#  'intervened',
#  'on',
#  'heller',
#  '’',
#  's',
#  'behalf',
#  '.',
#  '[',
#  'see',
#  'the',
#  'anti-heller',
#  'ad',
#  'here',
#  ']',
#  'trump',
#  'also',
#  'has',
#  'threatened',
#  'electoral',
#  'consequences',
#  'against',
#  'republican',
#  'senators',
#  'who',
#  'oppose',
#  'the',
#  'party',
#  'consensus',
#  'on',
#  'health',
#  'care',
#  '.',
#  '“',
#  'look',
#  ',',
#  'he',
#  'wants',
#  'to',
#  'remain',
#  'a',
#  'senator',
#  ',',
#  'doesn',
#  '’',
#  't',
#  'he',
#  '?',
#  '”',
#  'the',
#  'president',
#  'said',
#  'recently',
#  'of',
#  'heller',
#  ',',
#  'who',
#  'was',
#  'seated',
#  'next',
#  'to',
#  'him',
#  'at',
#  'a',
#  'lunch',
#  'event',
#  '.',
#  '“',
#  'i',
#  'think',
#  'the',
#  'people',
#  'of',
#  'your',
#  'state',
#  '.',
#  '.',
#  '.',
#  '[',
#  'are',
#  ']',
#  'going',
#  'to',
#  'appreciate',
#  'what',
#  'you',
#  'hopefully',
#  'will',
#  'do.',
#  '”',
#  'still',
#  ',',
#  'the',
#  'most',
#  'colorful',
#  'and',
#  'threatening',
#  'comments',
#  'have',
#  'targeted',
#  'collins',
#  'and',
#  'murkowski',
#  '.',
#  'rep.',
#  'blake',
#  'farenthold',
#  '(',
#  'tex',
#  '.',
#  ')',
#  ',',
#  'in',
#  'an',
#  'apparent',
#  'reference',
#  'to',
#  'collins',
#  ',',
#  'told',
#  'a',
#  'radio',
#  'host',
#  'friday',
#  'that',
#  'if',
#  'she',
#  'were',
#  'a',
#  '“',
#  'guy',
#  'from',
#  'south',
#  'texas',
#  ',',
#  'i',
#  'might',
#  'ask',
#  'him',
#  'to',
#  'step',
#  'outside',
#  'and',
#  'settle',
#  'this',
#  'aaron',
#  'burr-style',
#  ',',
#  '”',
#  'invoking',
#  'the',
#  '1804',
#  'duel',
#  'in',
#  'which',
#  'alexander',
#  'hamilton',
#  'was',
#  'killed',
#  '.',
#  '“',
#  'like',
#  'the',
#  'president',
#  ',',
#  'i',
#  'am',
#  'sick',
#  'and',
#  'tired',
#  'of',
#  'the',
#  'left-wing',
#  'biased',
#  'media',
#  'trying',
#  'to',
#  'make',
#  'something',
#  'out',
#  'of',
#  'nothing',
#  ',',
#  '”',
#  'he',
#  'said',
#  'in',
#  'a',
#  'follow-up',
#  'statement',
#  '.',
#  '“',
#  'this',
#  'was',
#  'clearly',
#  'tongue',
#  'in',
#  'cheek',
#  '.',
#  'that',
#  'being',
#  'said',
#  ',',
#  'i',
#  '’',
#  'm',
#  'extremely',
#  'frustrated',
#  'with',
#  'senate',
#  'republicans',
#  'who',
#  'are',
#  'breaking',
#  'their',
#  'promise',
#  'to',
#  'the',
#  'american',
#  'people',
#  'to',
#  'repeal',
#  'and',
#  'replace',
#  'obamacare.',
#  '”',
#  'collins',
#  'was',
#  'caught',
#  'on',
#  'a',
#  'hot',
#  'mic',
#  'responding',
#  ',',
#  'when',
#  'sen.',
#  'jack',
#  'reed',
#  '(',
#  'd-r.i.',
#  ')',
#  'said',
#  'she',
#  'could',
#  'beat',
#  'farenthold',
#  'in',
#  'such',
#  'a',
#  'duel',
#  '.',
#  'collins',
#  'called',
#  'fahrenthold',
#  '“',
#  'huge',
#  '”',
#  'and',
#  '“',
#  'extremely',
#  'unattractive.',
#  '”',
#  'they',
#  'later',
#  'apologized',
#  'to',
#  'each',
#  'other',
#  ',',
#  'cnn',
#  'reported',
#  '.',
#  'rep.',
#  'earl',
#  'l.',
#  '“',
#  'buddy',
#  '”',
#  'carter',
#  '(',
#  'r-ga.',
#  ')',
#  'told',
#  'msnbc',
#  'on',
#  'wednesday',
#  'that',
#  'someone',
#  'should',
#  '“',
#  'go',
#  'over',
#  'there',
#  'to',
#  'that',
#  'senate',
#  'and',
#  'snatch',
#  'a',
#  'knot',
#  'in',
#  'their',
#  'a',
#  '--',
#  ',',
#  '”',
#  'a',
#  'regional',
#  'phrase',
#  'that',
#  'refers',
#  'to',
#  'punishment',
#  ',',
#  'usually',
#  'of',
#  'disobedient',
#  'children',
#  '.',
#  'msnbc',
#  'reporter',
#  'ali',
#  'velshi',
#  'had',
#  'asked',
#  'carter',
#  'what',
#  'he',
#  'thought',
#  'of',
#  'trump',
#  '’',
#  's',
#  'tweet',
#  'chastising',
#  'murkowski',
#  'for',
#  'opposing',
#  'the',
#  'start',
#  'of',
#  'the',
#  'health-care',
#  'debate',
#  '.',
#  'carter',
#  'later',
#  'said',
#  'the',
#  'remark',
#  'was',
#  'directed',
#  'at',
#  'all',
#  'those',
#  'senators',
#  'who',
#  ',',
#  'like',
#  'murkowski',
#  ',',
#  'stood',
#  'in',
#  'the',
#  'way',
#  'of',
#  'easy',
#  'victory',
#  'for',
#  'the',
#  'legislation',
#  '.',
#  '“',
#  'rep',
#  '.',
#  'carter',
#  '’',
#  's',
#  'comment',
#  'was',
#  'in',
#  'no',
#  'way',
#  'directed',
#  'toward',
#  'senator',
#  'murkowski',
#  'specifically',
#  ',',
#  '”',
#  'carter',
#  'spokeswoman',
#  'mary',
#  'carpenter',
#  'wrote',
#  'in',
#  'an',
#  'email',
#  '.',
#  '“',
#  'his',
#  'words',
#  'speak',
#  'for',
#  'themselves',
#  'that',
#  'he',
#  'was',
#  'not',
#  'speaking',
#  'about',
#  'a',
#  'single',
#  'senator',
#  '.',
#  'this',
#  'is',
#  'a',
#  'southern',
#  'phrase',
#  'used',
#  'frequently',
#  'throughout',
#  'rep.',
#  'carter',
#  '’',
#  's',
#  'lifetime',
#  'which',
#  'simply',
#  'means',
#  'get',
#  'your',
#  'act',
#  'together.',
#  '”',
#  'the',
#  'comments',
#  'are',
#  'particularly',
#  'poignant',
#  ',',
#  'given',
#  'that',
#  'republican',
#  'women',
#  'in',
#  'the',
#  'senate',
#  'were',
#  'excluded',
#  'from',
#  'the',
#  'chamber',
#  '’',
#  's',
#  'original',
#  'working',
#  'group',
#  'on',
#  'health',
#  'care',
#  '.',
#  '“',
#  'it',
#  '’',
#  's',
#  'too',
#  'bad',
#  'some',
#  'folks',
#  'are',
#  'spending',
#  'so',
#  'much',
#  'time',
#  'creating',
#  'cute',
#  'catchy',
#  'phrases',
#  'in',
#  'order',
#  'to',
#  'take',
#  'potshots',
#  'at',
#  'colleagues',
#  ',',
#  '”',
#  'julie',
#  'a.',
#  'conway',
#  ',',
#  'executive',
#  'director',
#  ...]

# %% [markdown]
# ### Auto summarize by extracting the most important sentences

# %% [markdown]
# #### Frequency distribuition of words

# %%
from nltk.probability import FreqDist
freq = FreqDist(word_sent)
freq
# Out:
# FreqDist({'!': 1,
#           '$': 1,
#           '(': 10,
#           ')': 10,
#           ',': 49,
#           '--': 1,
#           '.': 44,
#           '1': 1,
#           '1804': 1,
#           '2010': 1,
#           ':': 1,
#           '?': 1,
#           '@': 1,
#           '[': 4,
#           ']': 4,
#           'a': 24,
#           'a.': 1,
#           'aaron': 1,
#           'about': 3,
#           'about.': 1,
#           'aca': 2,
#           'accelerate': 1,
#           'according': 2,
#           'act': 2,
#           'ad': 1,
#           'adopted': 1,
#           'ads': 1,
#           'affecting': 1,
#           'affordable': 1,
#           'after': 2,
#           'against': 3,
#           'aggressive': 1,
#           'alaska': 5,
#           'alexander': 1,
#           'ali': 1,
#           'all': 1,
#           'almost': 1,
#           'also': 1,
#           'am': 1,
#           'amber': 1,
#           'amend': 1,
#           'america': 1,
#           'american': 2,
#           'americans': 1,
#           'among': 1,
#           'an': 4,
#           'and': 25,
#           'announced': 1,
#           'anti-heller': 1,
#           'apologized': 1,
#           'apparent': 1,
#           'appreciate': 1,
#           'are': 7,
#           'argued': 1,
#           'as': 7,
#           'ask': 1,
#           'asked': 1,
#           'at': 8,
#           'attack': 1,
#           'attacks': 1,
#           'author': 1,
#           'backlash': 2,
#           'bad': 2,
#           'be': 2,
#           'beat': 1,
#           'because': 2,
#           'been': 4,
#           'behalf': 1,
#           'behavior': 1,
#           'being': 1,
#           'believed': 1,
#           'bias': 1,
#           'biased': 1,
#           'bill': 1,
#           'blake': 1,
#           'both': 2,
#           'bragging': 1,
#           'breaking': 1,
#           'buddy': 1,
#           'burr-style': 1,
#           'but': 3,
#           'by': 6,
#           'cabinet': 1,
#           'call': 2,
#           'called': 3,
#           'calm': 1,
#           'campaign': 2,
#           'campaigns.': 1,
#           'can': 2,
#           'canceled': 1,
#           'candidates': 1,
#           'capacity': 1,
#           'care': 4,
#           'carpenter': 1,
#           'carter': 6,
#           'catches': 1,
#           'catchy': 1,
#           'caught': 1,
#           'center': 1,
#           'chairman': 1,
#           'challenged': 1,
#           'challenges': 1,
#           'chamber': 1,
#           'chastising': 1,
#           'cheek': 1,
#           'children': 1,
#           'choice': 1,
#           'clear': 1,
#           'clearly': 1,
#           'cnn': 1,
#           'colleague': 1,
#           'colleagues': 1,
#           'collins': 7,
#           'colorful': 1,
#           'comment': 1,
#           'comments': 4,
#           'committee': 2,
#           'comparison': 1,
#           'concerns': 1,
#           'consensus': 2,
#           'consequences': 1,
#           'conservative': 1,
#           'consistently': 1,
#           'contrast': 1,
#           'contributed': 1,
#           'conway': 1,
#           'could': 3,
#           'country': 1,
#           'crafting': 1,
#           'creating': 1,
#           'criticized': 1,
#           'critics': 2,
#           'culture': 1,
#           'cut': 1,
#           'cute': 1,
#           'd-r.i.': 1,
#           'dan': 1,
#           'day': 2,
#           'dean': 1,
#           'debate': 3,
#           'debonis': 1,
#           'decisions': 1,
#           'deferred': 1,
#           'degrading': 1,
#           'deserve': 1,
#           'directed': 2,
#           'director': 1,
#           'disapproval': 1,
#           'disobedient': 1,
#           'dispatch': 1,
#           'dittmar': 3,
#           'do.': 1,
#           'doesn': 1,
#           'dominance': 1,
#           'dominated': 1,
#           'doubt': 1,
#           'down': 2,
#           'duel': 3,
#           'during': 1,
#           'each': 1,
#           'earl': 1,
#           'easy': 1,
#           'effort': 2,
#           'elected': 2,
#           'electoral': 1,
#           'email': 2,
#           'endangered': 1,
#           'energy': 2,
#           'event': 1,
#           'excluded': 1,
#           'executive': 1,
#           'experts': 1,
#           'extremely': 2,
#           'face': 1,
#           'faced': 1,
#           'facing': 1,
#           'fact': 1,
#           'fahrenthold': 1,
#           'farenthold': 2,
#           'federal': 1,
#           'feel': 2,
#           'female': 3,
#           'ferguson/the': 1,
#           'find': 1,
#           'first': 1,
#           'folks': 1,
#           'follow-up': 1,
#           'for': 12,
#           'frequently': 1,
#           'friday': 1,
#           'from': 3,
#           'frustrated': 1,
#           'funding': 1,
#           'further': 1,
#           'gates': 1,
#           'gendered': 2,
#           'get': 2,
#           'given': 1,
#           'go': 1,
#           'going': 1,
#           'good': 1,
#           'gop': 5,
#           'great': 1,
#           'groping': 1,
#           'group': 2,
#           'guy': 1,
#           'had': 2,
#           'hamilton': 1,
#           'handful': 1,
#           'has': 5,
#           'have': 6,
#           'he': 7,
#           'health': 2,
#           'health-care': 9,
#           'heller': 3,
#           'help': 1,
#           'her': 1,
#           'here': 1,
#           'him': 3,
#           'his': 1,
#           'hopefully': 1,
#           'host': 1,
#           'hot': 1,
#           'huge': 1,
#           'hundreds': 1,
#           'i': 5,
#           'if': 1,
#           'in': 28,
#           'including': 1,
#           'increasingly': 2,
#           'influence': 1,
#           'insults': 1,
#           'interior': 1,
#           'intervened': 1,
#           'invoked': 1,
#           'invoking': 1,
#           'is': 4,
#           'it': 6,
#           'its': 2,
#           'jack': 1,
#           'julie': 1,
#           'just': 1,
#           'kelly': 1,
#           'killed': 1,
#           'kinds': 1,
#           'knot': 1,
#           'l.': 1,
#           'lack': 1,
#           'language': 1,
#           'last': 1,
#           'later': 3,
#           'lawmaker': 1,
#           'lawmakers': 1,
#           'leader': 1,
#           'leaders': 2,
#           'leading': 1,
#           'left-wing': 1,
#           'legislation': 3,
#           'let': 1,
#           'levels': 1,
#           'lifetime': 1,
#           'like': 3,
#           'lisa': 1,
#           'lisamurkowski': 1,
#           'long': 1,
#           'look': 1,
#           'lunch': 1,
#           'm': 1,
#           'maine': 1,
#           'make': 1,
#           'male': 1,
#           'marks': 1,
#           'markup': 1,
#           'mary': 1,
#           'masculine': 1,
#           'may': 1,
#           'means': 1,
#           'media': 1,
#           'medicaid': 1,
#           'medical': 1,
#           'meeting': 1,
#           'men': 3,
#           'message': 1,
#           'mic': 1,
#           'might': 1,
#           'mike': 1,
#           'million': 1,
#           'mines': 1,
#           'modest': 1,
#           'month': 1,
#           'more': 1,
#           'morning': 1,
#           'most': 2,
#           'msnbc': 2,
#           'much': 2,
#           'murkowski': 10,
#           'natural': 1,
#           'navigating': 1,
#           'nev.': 1,
#           'news': 2,
#           'next': 2,
#           'no': 1,
#           'nominations': 1,
#           'norm': 1,
#           'not': 6,
#           'notably': 1,
#           'nothing': 1,
#           'numbers': 1,
#           'obamacare.': 1,
#           'observers': 1,
#           'of': 28,
#           'official': 1,
#           'officials': 2,
#           'okay': 2,
#           'on': 7,
#           'one': 1,
#           'only': 2,
#           'opened': 1,
#           'opening': 1,
#           'oppose': 1,
#           'opposing': 2,
#           'opposition': 1,
#           'or': 2,
#           'order': 1,
#           'original': 1,
#           'other': 2,
#           'others': 1,
#           'our': 1,
#           'out': 3,
#           'outfit': 1,
#           'outlet': 1,
#           'outside': 3,
#           'over': 2,
#           'overhaul': 2,
#           'pac': 1,
#           'panel': 1,
#           'parenthood': 1,
#           'particularly': 1,
#           'party': 5,
#           'past': 1,
#           'paul': 1,
#           'people': 3,
#           'person': 1,
#           'phrase': 2,
#           'phrases': 1,
#           'physical': 2,
#           'planned': 1,
#           'poignant': 1,
#           'pointed': 1,
#           'policies': 1,
#           'policy': 1,
#           'political': 3,
#           'politics': 1,
#           'post': 2,
#           'postponed': 2,
#           'potshots': 1,
#           'powerpost': 1,
#           'president': 3,
#           'pretty': 1,
#           'pro-trump': 1,
#           'progress': 1,
#           'promise': 1,
#           'proposals': 2,
#           'provide': 1,
#           'punishment': 1,
#           'qualified': 1,
#           'question': 1,
#           'r-alaska': 1,
#           'r-ga.': 1,
#           'r-ky.': 1,
#           'radio': 2,
#           'raised': 1,
#           'rand': 1,
#           'read': 1,
#           'real': 1,
#           'really': 1,
#           'recently': 1,
#           'recruits': 1,
#           'reed': 1,
#           'reference': 1,
#           'refers': 1,
#           'reflects': 1,
#           'reform': 1,
#           'regional': 1,
#           'remain': 1,
#           'remains': 1,
#           'remark': 1,
#           'rep': 1,
#           'rep.': 3,
#           'repeal': 1,
#           'repercussions': 1,
#           'replace': 1,
#           'report': 1,
#           'reported': 1,
#           'reporter': 1,
#           'reprimand': 1,
#           'republican': 7,
#           'republicans': 4,
#           'resources': 1,
#           'responding': 1,
#           'retaliation': 2,
#           'retribution': 1,
#           'revealing': 1,
#           'rhetoric': 1,
#           'round': 1,
#           'run': 1,
#           'rutgers': 1,
#           'ryan': 1,
#           's': 15,
#           'said': 9,
#           'say': 2,
#           'schedule': 1,
#           'scholar': 1,
#           'seated': 1,
#           'secretary': 1,
#           'see': 2,
#           'sen.': 6,
#           'senate': 7,
#           'senator': 4,
#           'senators': 3,
#           'senior': 1,
#           'settle': 1,
#           'she': 4,
#           'should': 1,
#           'shows': 1,
#           'sick': 1,
#           'simply': 1,
#           'single': 1,
#           'sitting': 1,
#           'skeptical': 1,
#           'snatch': 1,
#           'so': 1,
#           'solutions': 1,
#           'some': 3,
#           'someone': 1,
#           'something': 2,
#           'sorts': 1,
#           'south': 1,
#           'southern': 1,
#           'speak': 1,
#           'speaking': 1,
#           'specific': 1,
#           'specifically': 3,
#           'speculate': 1,
#           'spend': 1,
#           'spending': 1,
#           'spokeswoman': 2,
#           'start': 1,
#           'starting': 1,
#           'state': 2,
#           'statement': 1,
#           'states': 1,
#           'step': 1,
#           'stereotypes': 1,
#           'still': 1,
#           'stood': 1,
#           'strategy': 2,
#           'such': 2,
#           'suffer': 1,
#           'sullivan': 2,
#           'support': 1,
#           'supposed': 1,
#           'surfaced': 1,
#           'susan': 1,
#           't': 1,
#           'take': 1,
#           'targeted': 2,
#           'terms': 1,
#           'terrain': 1,
#           'tex': 1,
#           'texas': 1,
#           'that': 19,
#           'the': 57,
#           'their': 7,
#           'themselves': 1,
#           'there': 1,
#           'these': 2,
#           'they': 7,
#           'things': 1,
#           'think': 1,
#           'this': 5,
#           'this.': 1,
#           'those': 4,
#           'thought': 1,
#           'thousands': 1,
#           'threatened': 1,
#           'threatening': 1,
#           'throughout': 1,
#           'time': 2,
#           'times': 1,
#           'tired': 1,
#           'to': 30,
#           'together.': 1,
#           'told': 6,
#           'tongue': 1,
#           'too': 2,
#           'toward': 2,
#           'trains': 1,
#           'transparency': 1,
#           'trump': 6,
#           'trying': 1,
#           'tv': 1,
#           'tweet': 1,
#           'tweeted': 1,
#           'twitter': 1,
#           'unattractive.': 1,
#           'uncertainty': 1,
#           'underlying': 1,
#           'undermine': 1,
#           'underscores': 1,
#           'university': 1,
#           'up': 1,
#           'use': 1,
#           'used': 1,
#           'usually': 1,
#           'vein': 1,
#           'velshi': 1,
#           'victory': 1,
#           'videotape': 1,
#           'view': 1,
#           'voices': 1,
#           'vote': 1,
#           'voted': 1,
#           'votes': 1,
#           'vulgar': 1,
#           'wants': 1,
#           'was': 11,
#           'washington': 2,
#           'way': 2,
#           'we': 1,
#           'wednesday': 2,
#           'week': 2,
#           'were': 3,
#           'what': 2,
#           'when': 3,
#           'whether': 1,
#           'which': 5,
#           'who': 9,
#           'whose': 1,
#           'will': 1,
#           'wish': 1,
#           'with': 5,
#           'women': 10,
#           'words': 1,
#           'work': 1,
#           'working': 1,
#           'would': 2,
#           'wrote': 2,
#           'yesterday': 1,
#           'you': 1,
#           'your': 2,
#           'zinke': 2,
#           '—': 2,
#           '’': 17,
#           '“': 20,
#           '”': 20})

# %% [markdown]
# #### Compute significance score for each sentence in the article using the word frequency

# %%
from collections import defaultdict
ranking = defaultdict(int)

for i,sent in enumerate(sents):
    for w in word_tokenize(sent.lower()):
        if w in freq:
            ranking[i] += freq[w]

# %%
ranking
# Out:
# defaultdict(int,
#             {0: 372,
#              1: 315,
#              2: 279,
#              3: 508,
#              4: 523,
#              5: 422,
#              6: 1385,
#              7: 677,
#              8: 461,
#              9: 233,
#              10: 293,
#              11: 306,
#              12: 159,
#              13: 229,
#              14: 517,
#              15: 162,
#              16: 44,
#              17: 44,
#              18: 307,
#              19: 61,
#              20: 638,
#              21: 502,
#              22: 111,
#              23: 569,
#              24: 259,
#              25: 573,
#              26: 315,
#              27: 459,
#              28: 65,
#              29: 261,
#              30: 156,
#              31: 521,
#              32: 527,
#              33: 463,
#              34: 256,
#              35: 357,
#              36: 101,
#              37: 382,
#              38: 80,
#              39: 602,
#              40: 272,
#              41: 612,
#              42: 479,
#              43: 83,
#              44: 11})

# %% [markdown]
# #### The top most significant sentences

# %%
sents_idx = nlargest(4, ranking, key=ranking.get)

# %%
sents_idx
# Out:
# [6, 7, 20, 41]

# %% [markdown]
# #### Print our summary by putting togehter the most significant sentences

# %%
[sents[j] for j in sorted(sents_idx)]
# Out:
# ['“Masculine dominance in the Republican Party is not only in numbers but in culture,” said Kelly Dittmar, a scholar at the Center for American Women and Politics at Rutgers University and the author of “Navigating Gendered Terrain: Stereotypes and Strategy in Political Campaigns.”   “When the person who is supposed to be the leader of the party shows it’s okay to use those sorts of attacks, whether they are specifically gendered or not, that is something that catches on at other levels,” Dittmar said.',
#  '“We see it in the [elected officials] who feel it’s okay to say things like this.”       (Amber Ferguson/The Washington Post)    [Senate GOP leaders work to round up votes for modest health-care overhaul]  Collins and Murkowski have been among the Senate’s most consistently skeptical voices as Republicans accelerate their effort to amend the 2010 Affordable Care Act (ACA).',
#  '), in an apparent reference to Collins, told a radio host Friday that if she were a “guy from south Texas, I might ask him to step outside and settle this Aaron Burr-style,” invoking the 1804 duel in which Alexander Hamilton was killed.',
#  'The next day, a nominations markup in the Senate Energy and Natural Resources Committee was postponed, leading some observers to speculate that Murkowski — the panel’s chairman — had deferred it in retaliation for Zinke’s call.']

# %% [markdown]
# #### Module to summarize text given a text and number of sentences for the summary

# %%
def summarize(text, n):
    sents = sent_tokenize(text)
    
    assert n <= len(sents)
    word_sent = word_tokenize(text.lower())
    _stopwords = set(stopwords.words('english') + list(punctuation))
    
    word_sent=[word for word in word_sent if word not in _stopwords]
    freq = FreqDist(word_sent)
    
    
    ranking = defaultdict(int)
    
    for i,sent in enumerate(sents):
        for w in word_tokenize(sent.lower()):
            if w in freq:
                ranking[i] += freq[w]
             
        
    sents_idx = nlargest(n, ranking, key=ranking.get)
    return [sents[j] for j in sorted(sents_idx)]

# %%
summarize(text,3)
# Out:
# ['“Masculine dominance in the Republican Party is not only in numbers but in culture,” said Kelly Dittmar, a scholar at the Center for American Women and Politics at Rutgers University and the author of “Navigating Gendered Terrain: Stereotypes and Strategy in Political Campaigns.”   “When the person who is supposed to be the leader of the party shows it’s okay to use those sorts of attacks, whether they are specifically gendered or not, that is something that catches on at other levels,” Dittmar said.',
#  '“We see it in the [elected officials] who feel it’s okay to say things like this.”       (Amber Ferguson/The Washington Post)    [Senate GOP leaders work to round up votes for modest health-care overhaul]  Collins and Murkowski have been among the Senate’s most consistently skeptical voices as Republicans accelerate their effort to amend the 2010 Affordable Care Act (ACA).',
#  'Rep. Earl L. “Buddy” Carter (R-Ga.) told MSNBC on Wednesday that someone should “go over there to that Senate and snatch a knot in their a--,” a regional phrase that refers to punishment, usually of disobedient children.']
